# %%
import json
with open("./shortanswer_ratings_cache.json", 'r', encoding='utf-8') as f:
    sa_cache = json.load(f)

sa_qdict = {}
for qaid, qdata in sa_cache.items():
    qid = qdata['qid']
    if qid not in sa_qdict:
        sa_qdict[qid] = {"question": qdata['question'], "correct_answer": qdata['correct_answer']}

# %%
with open("./compiled_results_sqa/grok-3-latest_phase1_compiled.json", 'r', encoding='utf-8') as f:
    claude_results = json.load(f)

for qid in claude_results["results"].keys():
    if qid not in sa_qdict:
        print(f"Warning: {qid} not found in sa_qdict")

# %%
import re
from base_game_class import BaseGameClass

judge_model = "claude-opus-4-20250514"
sa_to_mc_file = "./SimpleMC.jsonl"

fout = open(sa_to_mc_file, 'a', encoding='utf-8')

judge = BaseGameClass(subject_id=None, subject_name=judge_model, is_human_player=False, log_dir=None)
sysprompt=""
prompt = """I need your help turning a short-answer quiz into a multiple-choice quiz. I'm going to show you a question and its correct answer, and I want you to generate three distractors. 
Each distractor should be a plausible answer that is NOT the correct answer. Each should be the same \"type\" of answer as the correct answer (e.g., date, person name, number, etc), and follow the format of the correct answer.
Output each distractor a separate line, and do not include any other text. Your entire response should be just the distractors, one per line.
Here is the question and correct answer:

Question: {question}

Correct Answer: {correct_answer}

Distractors:
"""
for ctr, (qid, qdata) in enumerate(sa_qdict.items()):
    question = qdata['question']
    correct_answer = qdata['correct_answer'].strip()
    print(f"Processing question {ctr+1}, ID: {qid}")
    
    while True:
        resp, _, _ = judge._get_llm_answer(options=None, q_text=prompt.format(question=question, correct_answer=correct_answer), message_history=[], keep_appending=False, setup_text=sysprompt, MAX_TOKENS=None, temp=1.0)
        ans_list = re.split(r'\n+', resp) if resp else []
        ans_set = set([a.strip().upper() for a in ans_list] + [correct_answer.upper()]) 
        if len(ans_set) == 4 and all(ans.strip() for ans in ans_list):
            break
        else:
            print(f"Invalid response format for question {qid}. Retrying...")
    fout.write(json.dumps({"qid": qid, "question": question, "correct_answer": correct_answer, "distractors": ans_list}, ensure_ascii=False) + "\n")
    fout.flush()
# Out:
# Provider: Anthropic
# Processing question 499, ID: sqa_test_2469
# In model_call, provider=Anthropic, attempt=1
# Processing question 500, ID: sqa_test_1573
# In model_call, provider=Anthropic, attempt=1

# %%
from load_and_format_datasets import load_and_format_dataset
qs=load_and_format_dataset("SimpleMC")
# Out:
# Attempting to load SimpleMC...
# Dataset loaded successfully.
# Attempting to load SimpleQA (test split)...
# Dataset loaded successfully.
# Formatting 4326 questions...
# Successfully formatted 4326 unique questions from SimpleQA.
# Formatting 500 questions...
# Successfully formatted 500 unique questions from SimpleMC.

# %%
for i, q in enumerate(qs):
    if q['question'] == 'Which of the three Olympic fencing weapons was the last one to transition to using electrical equipment?':
        print(f"Found question at index {i}: {q}")
        break
# Out:
# Found question at index 36: {'id': 'sqa_test_479', 'question': 'Which of the three Olympic fencing weapons was the last one to transition to using electrical equipment?', 'options': {'A': 'Sabre', 'B': 'Foil', 'C': 'Rapier', 'D': 'Épée'}, 'correct_answer': 'A', 'answer_type': 'Person', 'topic': 'Politics'}

# %%
sqa=load_and_format_dataset("SimpleQA")
# Out:
# Attempting to load SimpleQA (test split)...
# Dataset loaded successfully.
# Formatting 4326 questions...
# Successfully formatted 4326 unique questions from SimpleQA.

# %%
for i, q in enumerate(sqa):
    if q['question'] == 'Which of the three Olympic fencing weapons was the last one to transition to using electrical equipment?':
        print(f"Found question at index {i}: {q}")
        break
# Out:
# Found question at index 1500: {'id': 'sqa_test_789', 'question': 'Which of the three Olympic fencing weapons was the last one to transition to using electrical equipment?', 'correct_answer': 'Sabre', 'answer_type': 'Other', 'topic': 'Sports'}

# %%
import hashlib
import os
import json
def text_to_id(text):
    return "sqa_test_" + hashlib.sha256(text.encode('utf-8')).hexdigest()

## replace every "id" field value in "phase1_questions" and "phase2_questions" with a new id based on the "question" text, and every "question_id" in "results" with a new id based on the "question_text" text
for filename in os.listdir("delegate_game_logs"):
   if "_Simple" in filename and filename.endswith("_game_data.json"):
       fname = os.path.join("delegate_game_logs", filename)
       with open(fname, 'r', encoding='utf-8') as f:
           game_data = json.load(f)
       for q in game_data['phase1_questions']:
           q['id'] = text_to_id(q['question'])
       for q in game_data['phase2_questions']:
           q['id'] = text_to_id(q['question'])
       for q in game_data['results']:
           q['question_id'] = text_to_id(q['question_text'])
       with open(fname, 'w', encoding='utf-8') as f:
           json.dump(game_data, f, ensure_ascii=False, indent=2)

# %%
targ_dir = "compiled_results_sqa"
for filename in os.listdir(targ_dir):
   if not "claude-3-5-sonnet-20241022_phase1_compiled.json" in filename:
       continue
   if filename.endswith(".json"):
    fname = os.path.join(targ_dir, filename)
    with open(fname, 'r', encoding='utf-8') as f:
        game_data = json.load(f)
    
    # Create new results dict with updated keys
    new_results = {}
    for old_id, result_data in game_data['results'].items():
        new_id = text_to_id(result_data['question'])
        new_results[new_id] = result_data
    
    # Replace the results dict
    game_data['results'] = new_results
    
    with open(fname, 'w', encoding='utf-8') as f:
        json.dump(game_data, f, ensure_ascii=False, indent=2)

# %%
## check for duplicate ids
from collections import Counter
targ_dir = "compiled_results_sqa"
for filename in os.listdir(targ_dir):
   if filename.endswith(".json"):
    fname = os.path.join(targ_dir, filename)
    with open(fname, 'r', encoding='utf-8') as f:
        game_data = json.load(f)
    id_counts = Counter(game_data['results'].keys())
    duplicates = [id for id, count in id_counts.items() if count > 1]
    if duplicates:
        print(f"Duplicate IDs found in {filename}: {duplicates}")
    else:
        print(f"No duplicate IDs found in {filename}")
# Out:
# No duplicate IDs found in gemini-2.0-flash-001_phase1_compiled.json
# No duplicate IDs found in deepseek-chat_phase1_compiled.json
# No duplicate IDs found in gemini-2.5-flash-preview-04-17_phase1_compiled.json
# No duplicate IDs found in grok-3-latest_phase1_compiled.json
# No duplicate IDs found in gpt-4o-2024-08-06_phase1_compiled.json
# No duplicate IDs found in claude-sonnet-4-20250514_phase1_compiled.json
# No duplicate IDs found in claude-3-5-sonnet-20241022_phase1_compiled.json

# %% [markdown]
# # Convert PopQA to PopMC

# %%
import json
import re
import os
from base_game_class import BaseGameClass

judge_model = "claude-sonnet-4-20250514"
popqa_file = "./data/PopQA_test.jsonl"
popmc_file = "./data/PopMC.jsonl"

# Set how many questions to process (None for all questions)
max_questions = 15000  # Change this to None or a number to process all or a specific amount

# Initialize judge
judge = BaseGameClass(subject_id=None, subject_name=judge_model, is_human_player=False, log_dir=None)

sysprompt = ""
prompt = """I need your help turning a short-answer quiz into a multiple-choice quiz. I'm going to show you a question and a list of possible correct answers. 

First, select the most appropriate answer from the possible_answers list. This will be the correct answer.

Then, generate three distractors. Each distractor should be a plausible answer that is NOT the correct answer. Each should be the same "type" of answer as the correct answer (e.g., date, person name, number, occupation, etc), and follow the format of the correct answer.

Output format:
1. First line: The selected correct answer (exactly as it appears in possible_answers or a close variant)
2. Next three lines: The three distractors, one per line

Do not include any other text. Your entire response should be just the four answers, one per line.

Here is the question and possible answers:

Question: {question}

Possible Answers: {possible_answers}

Selected correct answer and distractors:
"""

# Load existing qids from popmc_file if it exists
existing_qids = set()
if os.path.exists(popmc_file):
    with open(popmc_file, 'r', encoding='utf-8') as f:
        for line in f:
            if line.strip():
                try:
                    existing_data = json.loads(line)
                    existing_qids.add(existing_data['qid'])
                except:
                    continue
    print(f"Found {len(existing_qids)} existing questions in {popmc_file}")

# Open file in append mode with context manager for safety
processed_count = 0
skipped_count = 0
checkpoint_interval = 10  # Print status every N questions

with open(popmc_file, 'a', encoding='utf-8') as fout:
    with open(popqa_file, 'r', encoding='utf-8') as f:
        for ctr, line in enumerate(f):
            # Check if we've reached max_questions
            if max_questions is not None and processed_count >= max_questions:
                print(f"Reached max_questions limit ({max_questions}). Stopping.")
                break
                
            if not line.strip():
                continue
                
            popqa_data = json.loads(line)
            
            # Extract needed fields
            qid = f"popmc_test_{popqa_data['id']}"
            
            # Check if this question already exists
            if qid in existing_qids:
                print(f"Skipping {qid} - already in {popmc_file}")
                skipped_count += 1
                continue
                
            question = popqa_data['question']
            possible_answers_str = popqa_data['possible_answers']
            prop = popqa_data['prop']
            s_pop = popqa_data['s_pop']
            o_pop = popqa_data['o_pop']
            
            # Parse possible_answers (it's a JSON string)
            try:
                possible_answers = json.loads(possible_answers_str)
            except:
                # If it's already a list or fails to parse, try to handle it
                if isinstance(possible_answers_str, list):
                    possible_answers = possible_answers_str
                else:
                    print(f"Warning: Could not parse possible_answers for {qid}. Skipping.")
                    continue
            
            # Format possible_answers as a readable string
            possible_answers_formatted = ", ".join([f'"{ans}"' for ans in possible_answers])
            
            print(f"Processing question {ctr+1}, ID: {qid}")
            
            try:
                while True:
                    resp, _, _ = judge._get_llm_answer(
                        options=None, 
                        q_text=prompt.format(question=question, possible_answers=possible_answers_formatted), 
                        message_history=[], 
                        keep_appending=False, 
                        setup_text=sysprompt, 
                        MAX_TOKENS=None, 
                        temp=1.0
                    )
                    
                    ans_list = re.split(r'\n+', resp) if resp else []
                    ans_list = [a.strip() for a in ans_list if a.strip()]
                    
                    if len(ans_list) >= 4:
                        correct_answer = ans_list[0]
                        distractors = ans_list[1:4]
                        
                        # Check that we have exactly 4 unique answers
                        ans_set = set([a.upper() for a in [correct_answer] + distractors])
                        if len(ans_set) == 4 and all(ans.strip() for ans in distractors):
                            break
                        else:
                            print(f"Invalid response format for question {qid}. Retrying...")
                    else:
                        print(f"Not enough answers returned for question {qid}. Got {len(ans_list)}. Retrying...")
                
                output_data = {
                    "qid": qid,
                    "question": question,
                    "correct_answer": correct_answer,
                    "distractors": distractors,
                    "prop": prop,
                    "s_pop": s_pop,
                    "o_pop": o_pop
                }
                
                # Write immediately and flush to ensure data is saved
                fout.write(json.dumps(output_data, ensure_ascii=False) + "\n")
                fout.flush()  # Force write to disk immediately
                
                # Add to existing_qids immediately to avoid duplicates if we resume
                existing_qids.add(qid)
                processed_count += 1
                
                # Periodic checkpoint message
                if processed_count % checkpoint_interval == 0:
                    print(f"Checkpoint: Processed {processed_count} questions so far...")
                
            except Exception as e:
                print(f"Error processing question {qid}: {e}")
                print(f"Continuing with next question. Progress saved: {processed_count} questions processed.")
                # Continue to next question instead of crashing
                continue

print(f"Conversion complete! Processed {processed_count} new questions, skipped {skipped_count} existing questions. Output written to {popmc_file}")
# Out:
# Provider: OpenRouter
# Found 4927 existing questions in ./data/PopMC.jsonl
# Skipping popmc_test_4222362 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4725190 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4382392 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4822110 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4011112 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1730929 - already in ./data/PopMC.jsonl
# Skipping popmc_test_276787 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1758574 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6339290 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6250781 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1223902 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4607081 - already in ./data/PopMC.jsonl
# Skipping popmc_test_596555 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3994636 - already in ./data/PopMC.jsonl
# Skipping popmc_test_394743 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4650739 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1085496 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4711830 - already in ./data/PopMC.jsonl
# Skipping popmc_test_783368 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2693461 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4419938 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3696050 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4651204 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2605479 - already in ./data/PopMC.jsonl
# Skipping popmc_test_839130 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5383283 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4087826 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3635613 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5982132 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3261572 - already in ./data/PopMC.jsonl
# Skipping popmc_test_857817 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6206947 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2657379 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3835721 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4198902 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3583128 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5807710 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4172941 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2303897 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3121959 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5120341 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3931528 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3174290 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1917994 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2224150 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1536600 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2218017 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5394168 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6539068 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1772720 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3553522 - already in ./data/PopMC.jsonl
# Skipping popmc_test_970059 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2092231 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2360504 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6416076 - already in ./data/PopMC.jsonl
# Skipping popmc_test_130213 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2311611 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3901091 - already in ./data/PopMC.jsonl
# Skipping popmc_test_837389 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2523400 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3275327 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1976296 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5052828 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5304362 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6110369 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6055820 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6384726 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4251288 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1872067 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1905981 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4973369 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5582866 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3154588 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1094065 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3780672 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6430975 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4244332 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1805806 - already in ./data/PopMC.jsonl
# Skipping popmc_test_900521 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1044970 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6042978 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4062418 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6135583 - already in ./data/PopMC.jsonl
# Skipping popmc_test_177542 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5571000 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5651252 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4265255 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4674890 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3111664 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1505982 - already in ./data/PopMC.jsonl
# Skipping popmc_test_371747 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3882000 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1056532 - already in ./data/PopMC.jsonl
# Skipping popmc_test_843797 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5178335 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1901465 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5254909 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1701577 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2951170 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5586772 - already in ./data/PopMC.jsonl
# Skipping popmc_test_584816 - already in ./data/PopMC.jsonl
# Skipping popmc_test_257764 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3116649 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2043042 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2171332 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2062111 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6392317 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3930846 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4817052 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2139096 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1479687 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2428794 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6490517 - already in ./data/PopMC.jsonl
# Skipping popmc_test_743705 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2861972 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3689415 - already in ./data/PopMC.jsonl
# Skipping popmc_test_399341 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2201087 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2101249 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5574760 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1642428 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2533751 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5431559 - already in ./data/PopMC.jsonl
# Skipping popmc_test_380651 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5576709 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5981733 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4626587 - already in ./data/PopMC.jsonl
# Skipping popmc_test_896602 - already in ./data/PopMC.jsonl
# Skipping popmc_test_705614 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6517629 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2348074 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3954287 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3151249 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4653283 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3889778 - already in ./data/PopMC.jsonl
# Skipping popmc_test_332566 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4918912 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5111257 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1348390 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4760447 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4411817 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4057234 - already in ./data/PopMC.jsonl
# Skipping popmc_test_917458 - already in ./data/PopMC.jsonl
# Skipping popmc_test_415791 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5138925 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2376692 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5855941 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5148350 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5032330 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2942698 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3727391 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2712125 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2629344 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5887509 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5704779 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3049219 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3310098 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2411732 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2876983 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1371300 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3455880 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2675510 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1790865 - already in ./data/PopMC.jsonl
# Skipping popmc_test_141296 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3884509 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1412677 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4700304 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2513644 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1046826 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3228628 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5394014 - already in ./data/PopMC.jsonl
# Skipping popmc_test_707302 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2738003 - already in ./data/PopMC.jsonl
# Skipping popmc_test_488360 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4032681 - already in ./data/PopMC.jsonl
# Skipping popmc_test_969078 - already in ./data/PopMC.jsonl
# Skipping popmc_test_381474 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4245478 - already in ./data/PopMC.jsonl
# Skipping popmc_test_267222 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1649869 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5761278 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5749211 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5930534 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3369181 - already in ./data/PopMC.jsonl
# Skipping popmc_test_873819 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2873463 - already in ./data/PopMC.jsonl
# Skipping popmc_test_190883 - already in ./data/PopMC.jsonl
# Skipping popmc_test_650179 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4007034 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1888642 - already in ./data/PopMC.jsonl
# Skipping popmc_test_503998 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2604063 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2464553 - already in ./data/PopMC.jsonl
# Skipping popmc_test_149790 - already in ./data/PopMC.jsonl
# Skipping popmc_test_378956 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1809727 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2111491 - already in ./data/PopMC.jsonl
# Skipping popmc_test_262900 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5358173 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4349875 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1451981 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3192627 - already in ./data/PopMC.jsonl
# Skipping popmc_test_549048 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2116285 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6408631 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3078887 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4161947 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1576553 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5243569 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3227256 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2303335 - already in ./data/PopMC.jsonl
# Skipping popmc_test_809091 - already in ./data/PopMC.jsonl
# Skipping popmc_test_969340 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6541952 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3998967 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3098902 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1422402 - already in ./data/PopMC.jsonl
# Skipping popmc_test_914998 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5331265 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1234983 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4749534 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1368385 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4018853 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3685425 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4179149 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4707538 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4345863 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6184317 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6530934 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4033957 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2308304 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1440910 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2083847 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4819464 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5545849 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1614694 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2616411 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4402552 - already in ./data/PopMC.jsonl
# Skipping popmc_test_115067 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6113213 - already in ./data/PopMC.jsonl
# Skipping popmc_test_63804 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1467376 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5865732 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4601630 - already in ./data/PopMC.jsonl
# Skipping popmc_test_71982 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3255483 - already in ./data/PopMC.jsonl
# Skipping popmc_test_99158 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1398108 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5580384 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4355272 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6498315 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3592141 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3885333 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3465542 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5576971 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1208074 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1487383 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3995369 - already in ./data/PopMC.jsonl
# Skipping popmc_test_541381 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1706404 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3061785 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2840460 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3996035 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3869212 - already in ./data/PopMC.jsonl
# Skipping popmc_test_54966 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6269132 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4265197 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3062555 - already in ./data/PopMC.jsonl
# Skipping popmc_test_138405 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4161309 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1175079 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4760220 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5814752 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5365158 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2179514 - already in ./data/PopMC.jsonl
# Skipping popmc_test_925304 - already in ./data/PopMC.jsonl
# Skipping popmc_test_832142 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4762905 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5748053 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1594309 - already in ./data/PopMC.jsonl
# Skipping popmc_test_610662 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3682685 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6545655 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1693978 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1369273 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4807954 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5600889 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3553978 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4736716 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4076650 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2918829 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5134878 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1074965 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1881398 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4895544 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4516560 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5646991 - already in ./data/PopMC.jsonl
# Skipping popmc_test_393580 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4702733 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2289441 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2992879 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4185917 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6388150 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5242688 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2562576 - already in ./data/PopMC.jsonl
# Skipping popmc_test_303478 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4271174 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5835166 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3978839 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6406481 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4487088 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1557995 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2976764 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3730569 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2546796 - already in ./data/PopMC.jsonl
# Skipping popmc_test_719085 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2863647 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1914727 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2059763 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2181704 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1658579 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5573629 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3970041 - already in ./data/PopMC.jsonl
# Skipping popmc_test_819155 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1136027 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6493078 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2492953 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2499057 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2513245 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5364913 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3073609 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5604342 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1338317 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5154012 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2827342 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3917737 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3378338 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5463140 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2525215 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5369942 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1542205 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4346605 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5367070 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1046216 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1419550 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2542370 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3393810 - already in ./data/PopMC.jsonl
# Skipping popmc_test_283289 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2297573 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5436371 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5575241 - already in ./data/PopMC.jsonl
# Skipping popmc_test_164717 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2649572 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2573242 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1832547 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3042619 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3056492 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4027096 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1654794 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3146386 - already in ./data/PopMC.jsonl
# Skipping popmc_test_465467 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5436227 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1412527 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1245440 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1424448 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1197254 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1541610 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1585914 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6194521 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2155451 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1446642 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5578702 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3025283 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6016753 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2344027 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5978662 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3820915 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5695286 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1761978 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5980495 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2901881 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6175762 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4155023 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5577511 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1697175 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1688093 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4381377 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2758402 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3287643 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1990787 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5741933 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2393310 - already in ./data/PopMC.jsonl
# Skipping popmc_test_996280 - already in ./data/PopMC.jsonl
# Skipping popmc_test_609565 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2416276 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6452892 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3528532 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5417853 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4011407 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2251381 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2566059 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1425557 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4999192 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4920389 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2740658 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2547392 - already in ./data/PopMC.jsonl
# Skipping popmc_test_969914 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5375427 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3255842 - already in ./data/PopMC.jsonl
# Skipping popmc_test_542248 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3266488 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2250993 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2885537 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4168123 - already in ./data/PopMC.jsonl
# Skipping popmc_test_765693 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2765775 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5773194 - already in ./data/PopMC.jsonl
# Skipping popmc_test_23500 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4219992 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2536013 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1566723 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5157909 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3342671 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4285368 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1053271 - already in ./data/PopMC.jsonl
# Skipping popmc_test_836769 - already in ./data/PopMC.jsonl
# Skipping popmc_test_932712 - already in ./data/PopMC.jsonl
# Skipping popmc_test_508193 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4208555 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3950869 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3588016 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1057932 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3109247 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5547877 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3538090 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6375207 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1406824 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1134377 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3072617 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2011238 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4805477 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1046764 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1074391 - already in ./data/PopMC.jsonl
# Skipping popmc_test_923364 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4180541 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6422375 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3407518 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3694493 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2363117 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1722071 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2384728 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4562802 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1688359 - already in ./data/PopMC.jsonl
# Skipping popmc_test_326188 - already in ./data/PopMC.jsonl
# Skipping popmc_test_980948 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5275031 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1862353 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6027741 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2175983 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4218380 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5022237 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2523660 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1587190 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2823825 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3900281 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1817033 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5713334 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2609028 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4503284 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5716400 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2529132 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4776718 - already in ./data/PopMC.jsonl
# Skipping popmc_test_394628 - already in ./data/PopMC.jsonl
# Skipping popmc_test_922670 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5731128 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6220880 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6269853 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4168234 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4657607 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2915101 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2996750 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5985932 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6173288 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1484274 - already in ./data/PopMC.jsonl
# Skipping popmc_test_285248 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6355702 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2263587 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3919096 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6112233 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6088731 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2385161 - already in ./data/PopMC.jsonl
# Skipping popmc_test_658003 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2567490 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2690917 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2260298 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1989375 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1762839 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4741585 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5276362 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5149643 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1158868 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2576955 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1938800 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2501291 - already in ./data/PopMC.jsonl
# Skipping popmc_test_154906 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5598035 - already in ./data/PopMC.jsonl
# Skipping popmc_test_652177 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4331418 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3869040 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2051142 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1713701 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5747555 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5378331 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4177778 - already in ./data/PopMC.jsonl
# Skipping popmc_test_298388 - already in ./data/PopMC.jsonl
# Skipping popmc_test_841679 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1504171 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5294096 - already in ./data/PopMC.jsonl
# Skipping popmc_test_392596 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1419959 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2120061 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3403435 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1204905 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3939174 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4646096 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3866633 - already in ./data/PopMC.jsonl
# Skipping popmc_test_149716 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4046450 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4493412 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3752840 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1236346 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1546461 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2197943 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4482534 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4296043 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3689273 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3119947 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4814012 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1644539 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1158077 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1356748 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4914600 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1089786 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5621482 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1251460 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2737157 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6191678 - already in ./data/PopMC.jsonl
# Skipping popmc_test_324999 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4528405 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3834239 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1291139 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6315935 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3036567 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6414075 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5728623 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1974597 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3089923 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3409836 - already in ./data/PopMC.jsonl
# Skipping popmc_test_386932 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3916727 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3332240 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3485927 - already in ./data/PopMC.jsonl
# Skipping popmc_test_298892 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1040220 - already in ./data/PopMC.jsonl
# Skipping popmc_test_880910 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5178526 - already in ./data/PopMC.jsonl
# Skipping popmc_test_383351 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3847314 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4335578 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3093988 - already in ./data/PopMC.jsonl
# Skipping popmc_test_232809 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3009952 - already in ./data/PopMC.jsonl
# Skipping popmc_test_325021 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1360393 - already in ./data/PopMC.jsonl
# Skipping popmc_test_760352 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5440620 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5677592 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4626488 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2392547 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4300406 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6365723 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2629754 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3454738 - already in ./data/PopMC.jsonl
# Skipping popmc_test_37346 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3390452 - already in ./data/PopMC.jsonl
# Skipping popmc_test_790430 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2762597 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6086681 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1566943 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5193895 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1411599 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4953132 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4320975 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6506409 - already in ./data/PopMC.jsonl
# Skipping popmc_test_167666 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2245900 - already in ./data/PopMC.jsonl
# Skipping popmc_test_293476 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3027836 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2962543 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3075565 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2693771 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1011657 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6536296 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1030164 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2746781 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5993862 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4996780 - already in ./data/PopMC.jsonl
# Skipping popmc_test_467655 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1141201 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5308304 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3531642 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2478495 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3871417 - already in ./data/PopMC.jsonl
# Skipping popmc_test_801894 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5034119 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3738444 - already in ./data/PopMC.jsonl
# Skipping popmc_test_389916 - already in ./data/PopMC.jsonl
# Skipping popmc_test_903653 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5269564 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5117704 - already in ./data/PopMC.jsonl
# Skipping popmc_test_224059 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3113315 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1692428 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1158175 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5267967 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4980703 - already in ./data/PopMC.jsonl
# Skipping popmc_test_596918 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1233512 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5006548 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3320295 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1231270 - already in ./data/PopMC.jsonl
# Skipping popmc_test_197777 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3597399 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1159122 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2657850 - already in ./data/PopMC.jsonl
# Skipping popmc_test_967077 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1302705 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2318096 - already in ./data/PopMC.jsonl
# Skipping popmc_test_553274 - already in ./data/PopMC.jsonl
# Skipping popmc_test_565838 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2609987 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2743141 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2748982 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5576441 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2996059 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3746560 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2312795 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6020401 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1756417 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1632004 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4246734 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5424079 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2848601 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5424513 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3853710 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5456079 - already in ./data/PopMC.jsonl
# Skipping popmc_test_940200 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6527690 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1427860 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1139143 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4674280 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5867034 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5159397 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2099338 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2842700 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3324967 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3292682 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5200244 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2109248 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2086865 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5639301 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1918732 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4286548 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3937456 - already in ./data/PopMC.jsonl
# Skipping popmc_test_21897 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3827230 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2118274 - already in ./data/PopMC.jsonl
# Skipping popmc_test_815798 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4548858 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3387429 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2412381 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4557690 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3981349 - already in ./data/PopMC.jsonl
# Skipping popmc_test_223230 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2065688 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3028114 - already in ./data/PopMC.jsonl
# Skipping popmc_test_714110 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2013686 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5473087 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2702752 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3356649 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5405575 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3946774 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6292892 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5079256 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2996652 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6453369 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6175216 - already in ./data/PopMC.jsonl
# Skipping popmc_test_559300 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3265386 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4886186 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1715386 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1349825 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3886435 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3150882 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1609681 - already in ./data/PopMC.jsonl
# Skipping popmc_test_15917 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2894564 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2009603 - already in ./data/PopMC.jsonl
# Skipping popmc_test_500004 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2167964 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6450718 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3899079 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5316162 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2346730 - already in ./data/PopMC.jsonl
# Skipping popmc_test_617409 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1514591 - already in ./data/PopMC.jsonl
# Skipping popmc_test_901608 - already in ./data/PopMC.jsonl
# Skipping popmc_test_724502 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1789490 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1040610 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1582387 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2609523 - already in ./data/PopMC.jsonl
# Skipping popmc_test_775412 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1695756 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1849941 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2260300 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4870620 - already in ./data/PopMC.jsonl
# Skipping popmc_test_645909 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1449832 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1545923 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3001169 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3917655 - already in ./data/PopMC.jsonl
# Skipping popmc_test_823276 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3106384 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5091341 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3946349 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2831250 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5245724 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2118085 - already in ./data/PopMC.jsonl
# Skipping popmc_test_604250 - already in ./data/PopMC.jsonl
# Skipping popmc_test_491829 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5060276 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3821193 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3581916 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6312455 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5432259 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3020486 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5707753 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4788687 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5047005 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5371008 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4886017 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5316517 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2470274 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5369598 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3048422 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3825824 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1684735 - already in ./data/PopMC.jsonl
# Skipping popmc_test_564506 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2843976 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4591465 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5451035 - already in ./data/PopMC.jsonl
# Skipping popmc_test_729239 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3987120 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5415509 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4067819 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5760382 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3270447 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4338636 - already in ./data/PopMC.jsonl
# Skipping popmc_test_189795 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4651098 - already in ./data/PopMC.jsonl
# Skipping popmc_test_597584 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3927677 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2820569 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2314595 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5117100 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2014591 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2483706 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1952542 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3117060 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2738040 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1002532 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4733160 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5206146 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2603928 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5269196 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4994752 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4395119 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6515003 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4118504 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3909798 - already in ./data/PopMC.jsonl
# Skipping popmc_test_3255449 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5900142 - already in ./data/PopMC.jsonl
# Skipping popmc_test_5829140 - already in ./data/PopMC.jsonl
# Skipping popmc_test_1056000 - already in ./data/PopMC.jsonl
# Skipping popmc_test_4344063 - already in ./data/PopMC.jsonl
# Skipping popmc_test_2118978 - already in ./data/PopMC.jsonl
# Skipping popmc_test_6506233 - already in ./data/PopMC.jsonl
# Skipping popmc_test_804877 - already in ./data/PopMC.jsonl
# ...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14149, ID: popmc_test_1592046
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14150, ID: popmc_test_3481503
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14151, ID: popmc_test_6242848
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14152, ID: popmc_test_1904656
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14153, ID: popmc_test_5815032
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14154, ID: popmc_test_2513496
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14155, ID: popmc_test_5967265
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14156, ID: popmc_test_5407282
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14157, ID: popmc_test_2658151
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9230 questions so far...
# Processing question 14158, ID: popmc_test_6260898
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14159, ID: popmc_test_2438406
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14160, ID: popmc_test_1388910
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14161, ID: popmc_test_1146607
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14162, ID: popmc_test_1672533
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14163, ID: popmc_test_5421647
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14164, ID: popmc_test_376088
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14165, ID: popmc_test_304997
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14166, ID: popmc_test_1505834
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14167, ID: popmc_test_1886934
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9240 questions so far...
# Processing question 14168, ID: popmc_test_356978
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14169, ID: popmc_test_6041536
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14170, ID: popmc_test_1856673
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14171, ID: popmc_test_1911900
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14172, ID: popmc_test_367189
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14173, ID: popmc_test_3447132
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14174, ID: popmc_test_3435393
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14175, ID: popmc_test_5006891
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14176, ID: popmc_test_3557457
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14177, ID: popmc_test_6505231
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9250 questions so far...
# Processing question 14178, ID: popmc_test_6403523
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14179, ID: popmc_test_4616163
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14180, ID: popmc_test_1752279
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14181, ID: popmc_test_4617076
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14182, ID: popmc_test_60523
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14183, ID: popmc_test_216682
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14184, ID: popmc_test_5895957
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14185, ID: popmc_test_6279762
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14186, ID: popmc_test_1202714
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14187, ID: popmc_test_81949
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9260 questions so far...
# Processing question 14188, ID: popmc_test_981550
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14189, ID: popmc_test_3747076
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14190, ID: popmc_test_6322925
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14191, ID: popmc_test_6604
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14192, ID: popmc_test_5347843
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14193, ID: popmc_test_1688733
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14194, ID: popmc_test_351597
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14195, ID: popmc_test_1347439
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14196, ID: popmc_test_1026190
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14197, ID: popmc_test_4073090
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9270 questions so far...
# Processing question 14198, ID: popmc_test_44382
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14199, ID: popmc_test_1357592
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14200, ID: popmc_test_1706834
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14201, ID: popmc_test_804606
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14202, ID: popmc_test_3447901
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14203, ID: popmc_test_3587971
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14204, ID: popmc_test_282751
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14205, ID: popmc_test_1793343
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14206, ID: popmc_test_336967
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14207, ID: popmc_test_2600825
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9280 questions so far...
# Processing question 14208, ID: popmc_test_168423
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14209, ID: popmc_test_4577192
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14210, ID: popmc_test_5623381
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14211, ID: popmc_test_6257265
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14212, ID: popmc_test_3636894
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14213, ID: popmc_test_6015165
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14214, ID: popmc_test_1573571
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14215, ID: popmc_test_451809
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14216, ID: popmc_test_1055100
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14217, ID: popmc_test_225131
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9290 questions so far...
# Processing question 14218, ID: popmc_test_512415
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14219, ID: popmc_test_248641
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14220, ID: popmc_test_593981
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14221, ID: popmc_test_3671245
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14222, ID: popmc_test_306840
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14223, ID: popmc_test_5714816
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14224, ID: popmc_test_2328856
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14225, ID: popmc_test_3716123
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14226, ID: popmc_test_3524029
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14227, ID: popmc_test_297952
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9300 questions so far...
# Processing question 14228, ID: popmc_test_1785792
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14229, ID: popmc_test_3656245
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14230, ID: popmc_test_6402884
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14231, ID: popmc_test_352365
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14232, ID: popmc_test_2211267
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14233, ID: popmc_test_2627781
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14234, ID: popmc_test_5467380
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14235, ID: popmc_test_10956
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14236, ID: popmc_test_5660051
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14237, ID: popmc_test_2970947
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9310 questions so far...
# Processing question 14238, ID: popmc_test_6554019
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14239, ID: popmc_test_2940712
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14240, ID: popmc_test_1616396
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14241, ID: popmc_test_1844051
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14242, ID: popmc_test_3364203
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14243, ID: popmc_test_832908
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14244, ID: popmc_test_1303276
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14245, ID: popmc_test_6305992
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14246, ID: popmc_test_34246
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14247, ID: popmc_test_2665279
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9320 questions so far...
# Processing question 14248, ID: popmc_test_2935548
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14249, ID: popmc_test_1854999
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14250, ID: popmc_test_542552
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14251, ID: popmc_test_2057677
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14252, ID: popmc_test_595538
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14253, ID: popmc_test_1202712
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14254, ID: popmc_test_1924631
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14255, ID: popmc_test_104224
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14256, ID: popmc_test_6292195
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14257, ID: popmc_test_2158825
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9330 questions so far...
# Processing question 14258, ID: popmc_test_318560
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14259, ID: popmc_test_654471
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14260, ID: popmc_test_1192195
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14261, ID: popmc_test_287919
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14262, ID: popmc_test_307811
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14263, ID: popmc_test_4165948
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14264, ID: popmc_test_2617063
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14265, ID: popmc_test_471864
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14266, ID: popmc_test_2965573
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Processing question 14267, ID: popmc_test_802449
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: Processed 9340 questions so far...
# Conversion complete! Processed 9340 new questions, skipped 4927 existing questions. Output written to ./data/PopMC.jsonl

# %% [markdown]
# # Convert unfiltered TriviaQA questions to TriviaMC

# %%
import json
import os
import re
import time
from base_game_class import BaseGameClass

# Model choice
judge_model = "claude-opus-4-1-20250805"
triviaqa_dev_file = "./data/unfiltered-web-dev.json"
triviamc_file = "./data/TriviaMC.jsonl"
rejections_file = "./data/TriviaQA_fact_checked_rejections.jsonl"
max_questions = None  # None for full run

trivia_judge = BaseGameClass(
    subject_id=None,
    subject_name=judge_model,
    is_human_player=False,
    log_dir=None,
)

# ---------- UNIFIED PROMPT ----------
trivia_sysprompt = ""
unified_prompt = """You are reviewing a trivia question for factual accuracy and converting it into multiple-choice format.

1. **First, check the factual accuracy** of the question and its candidate answers.
   - Be objective, not pedantic.
   - Do not correct or rewrite the question yourself.
   - If there is any potential factual inaccuracy, outdated information, or ambiguity, flag it and explain briefly why.
   - Otherwise, if the question seems factually valid, mark it as OK.

2. **If the question is OK**, generate a multiple-choice question using the original wording:
   - Use one correct answer (the best alias).
   - Create three plausible distractors of the same type.
   - Do not alter the original question text.

Output format:
If valid:
VALID
Correct: <correct answer>
Distractors:
- <distractor 1>
- <distractor 2>
- <distractor 3>

If there are factual concerns:
FLAGGED
Reason: <short explanation why this question may be inaccurate>

Question: {question}
Candidate aliases: {possible_answers}
"""


# ---------- HELPER FUNCTIONS ----------

def collect_aliases(entry):
    """Extract all possible aliases from a TriviaQA-style entry."""
    answer = entry.get("Answer") or {}
    alias_candidates = []
    for key in ("Aliases", "NormalizedAliases"):
        values = answer.get(key) or []
        if isinstance(values, list):
            alias_candidates.extend(values)
    for key in ("Value", "MatchedWikiEntityName", "NormalizedValue"):
        value = answer.get(key)
        if isinstance(value, str):
            alias_candidates.append(value)
    cleaned = []
    for alias in alias_candidates:
        alias = alias.strip()
        if alias and alias not in cleaned:
            cleaned.append(alias)
    return cleaned


# ---------- LOAD EXISTING DATA ----------
existing_qids = set()
existing_questions = set()
rejected_questions = set()
next_trivia_id = 0

if os.path.exists(triviamc_file):
    with open(triviamc_file, "r", encoding="utf-8") as existing_file:
        for line in existing_file:
            if not line.strip():
                continue
            try:
                record = json.loads(line)
            except json.JSONDecodeError:
                continue
            qid = record.get("qid")
            question_text = record.get("question", "").strip().lower()
            if qid:
                existing_qids.add(qid)
                if qid.startswith("triviamc_"):
                    try:
                        idx = int(qid.split("_", 1)[1])
                        next_trivia_id = max(next_trivia_id, idx + 1)
                    except ValueError:
                        pass
            if question_text:
                existing_questions.add(question_text)

if os.path.exists(rejections_file):
    with open(rejections_file, "r", encoding="utf-8") as reject_file:
        for line in reject_file:
            if not line.strip():
                continue
            try:
                record = json.loads(line)
            except json.JSONDecodeError:
                continue
            qid = record.get("qid")
            question_text = record.get("question", "").strip().lower()
            if qid and qid.startswith("triviamc_"):
                try:
                    idx = int(qid.split("_", 1)[1])
                    next_trivia_id = max(next_trivia_id, idx + 1)
                except ValueError:
                    pass
            if question_text:
                rejected_questions.add(question_text)

print(f"Resuming from triviamc_{next_trivia_id}")
print(f"Found {len(existing_qids)} accepted and {len(existing_questions)} unique questions in {triviamc_file}")
print(f"Found {len(rejected_questions)} rejected questions in {rejections_file}")

# ---------- LOAD SOURCE DATA ----------
with open(triviaqa_dev_file, "r", encoding="utf-8") as f:
    data = json.load(f)

dev_questions = data.get("Data", data) if isinstance(data, dict) else data
print(f"Loaded {len(dev_questions)} raw trivia questions")

# ---------- PROCESS ----------
processed, skipped = 0, 0
checkpoint = 10

with open(triviamc_file, "a", encoding="utf-8") as trivia_out, \
     open(rejections_file, "a", encoding="utf-8") as reject_out:

    for entry in dev_questions:
        if max_questions and processed + skipped >= max_questions:
            print(f"Reached max_questions={max_questions}. Stopping.")
            break

        aliases = collect_aliases(entry)
        question_text = (entry.get("Question") or "").strip()
        if not aliases or not question_text:
            skipped += 1
            continue

        normalized_q = question_text.lower()
        if normalized_q in existing_questions:
            print(f"Skipping duplicate: {question_text[:80]}")
            skipped += 1
            continue

        if normalized_q in rejected_questions:
            print(f"Skipping previously rejected: {question_text[:80]}")
            skipped += 1
            continue

        # Always increment QID — even if rejected, we log it
        qid = f"triviamc_{next_trivia_id}"
        next_trivia_id += 1
        possible_answers = ", ".join([f'"{a}"' for a in aliases])

        print(f"\nProcessing {qid}: {question_text[:80]}...")

        # Retry logic for rate limit errors
        max_retries = 5
        retry_delay = 2  # Start with 2 seconds
        response = None
        
        for attempt in range(max_retries):
            try:
                response, _, _ = trivia_judge._get_llm_answer(
                    options=None,
                    q_text=unified_prompt.format(
                        question=question_text,
                        possible_answers=possible_answers,
                    ),
                    message_history=[],
                    keep_appending=False,
                    setup_text=trivia_sysprompt,
                    MAX_TOKENS=None,
                    temp=0.7,
                )
                
                if response:
                    break  # Success, exit retry loop
                    
            except Exception as e:
                error_str = str(e)
                # Check if it's a rate limit error
                if "429" in error_str or "rate" in error_str.lower() or "RateLimitError" in error_str:
                    if attempt < max_retries - 1:
                        wait_time = retry_delay * (2 ** attempt)  # Exponential backoff
                        print(f"⚠️ Rate limit hit for {qid}. Waiting {wait_time}s before retry {attempt + 1}/{max_retries}...")
                        time.sleep(wait_time)
                        continue
                    else:
                        print(f"⚠️ Rate limit error for {qid} after {max_retries} attempts. Skipping.")
                        skipped += 1
                        break
                else:
                    # Non-rate-limit error, re-raise to be handled by outer try-except
                    raise
        
        if not response:
            print(f"⚠️ No response for {qid}. Skipping.")
            skipped += 1
            continue
        
        try:

            resp = response.strip()

            if resp.startswith("FLAGGED"):
                # Extract reason and log to rejections file
                m = re.search(r"Reason:\s*(.*)", resp, re.I)
                reason = m.group(1).strip() if m else "Unspecified concern"
                print(f"⚠️ Flagged {qid}: {reason}")
                reject_out.write(json.dumps({
                    "qid": qid,
                    "question": question_text,
                    "aliases": aliases,
                    "reason": reason
                }, ensure_ascii=False) + "\n")
                reject_out.flush()
                skipped += 1
                # Small delay to avoid hitting rate limits
                time.sleep(0.5)
                continue

            elif resp.startswith("VALID"):
                # Same parsing logic as before, but do NOT rewrite question
                c_match = re.search(r"Correct:\s*(.+)", resp)
                d_matches = re.findall(r"-\s*(.+)", resp)
                if c_match and len(d_matches) >= 3:
                    correct_answer = c_match.group(1).strip()
                    distractors = d_matches[:3]
                else:
                    print(f"⚠️ Invalid format for {qid}. Skipping.")
                    skipped += 1
                    continue

                trivia_out.write(json.dumps({
                    "qid": qid,
                    "question": question_text,  # keep original
                    "correct_answer": correct_answer,
                    "distractors": distractors
                }, ensure_ascii=False) + "\n")


             
                trivia_out.flush()
                existing_qids.add(qid)
                existing_questions.add(question_text.lower())
                processed += 1

                if processed % checkpoint == 0:
                    print(f"Checkpoint: {processed} accepted questions so far.")
                
                # Small delay to avoid hitting rate limits
                time.sleep(0.5)

            else:
                print(f"⚠️ Unrecognized response format for {qid}. Skipping.")
                skipped += 1

        except Exception as e:
            print(f"Error processing {qid}: {e}")
            skipped += 1
            continue

print(f"\n✅ Conversion complete. Accepted {processed}, rejected {skipped}.")
print(f"Accepted written to {triviamc_file}")
print(f"Rejected logged to {rejections_file}")
# Out:
# Provider: OpenRouter
# Resuming from triviamc_2883
# Found 2403 accepted and 2403 unique questions in ./data/TriviaMC.jsonl
# Found 302 rejected questions in ./data/TriviaQA_fact_checked_rejections.jsonl
# Loaded 11313 raw trivia questions
# Skipping duplicate: Who was the man behind The Chipmunks?
# Skipping duplicate: What star sign is Jamie Lee Curtis?
# Skipping duplicate: Which Lloyd Webber musical premiered in the US on 10th December 1993?
# Skipping duplicate: Who was the next British Prime Minister after Arthur Balfour?
# Skipping previously rejected: Who had a 70s No 1 hit with Kiss You All Over?
# Skipping duplicate: What claimed the life of singer Kathleen Ferrier?
# Skipping duplicate: Rita Coolidge sang the title song for which Bond film?
# Skipping previously rejected: To the nearest million what is the population of Australia?
# Skipping previously rejected: What was the last US state to reintroduce alcohol after prohibition?
# Skipping duplicate: Which actress was voted Miss Greenwich Village in 1942?
# Skipping duplicate: What is the Japanese share index called?
# Skipping duplicate: What was the name of Michael Jackson's autobiography written in 1988?
# Skipping duplicate: In which decade did stereo records first go on sale?
# Skipping duplicate: What was golfing great Ben Hogan's famous reply when he was asked how to improve
# Skipping duplicate: In what year's Olympics were electric timing devices and a public-address system
# Skipping duplicate: Why is the site of a boxing match called a ring when it's square?
# Skipping previously rejected: In the very first Boston Marathon, 15 runners competed. How many finished?
# Skipping previously rejected: "How many different animal shapes are there in the ""Animal Crackers"" cookie zo
# Skipping duplicate: Which volcano in Tanzania is the highest mountain in Africa?
# Skipping previously rejected: The flag of Libya is a plain rectangle of which color?
# Skipping duplicate: Of which African country is Niamey the capital?
# Skipping previously rejected: Who was the director of the CIA from 1976-81?
# Skipping duplicate: Which musical featured the song The Street Where You Live?
# Skipping duplicate: "Who was the target of the failed ""Bomb Plot"" of 1944?"
# Skipping duplicate: Who had an 80s No 1 hit with Hold On To The Nights?
# Skipping duplicate: Who directed the classic 30s western Stagecoach?
# Skipping previously rejected: Dave Gilmore and Roger Waters were in which rock group?
# Skipping duplicate: Which highway was Revisited in a classic 60s album by Bob Dylan?
# Skipping duplicate: Which was the only eastern bloc country to participate in the 1984 LA Olympics?
# Skipping duplicate: Which 90s sci fi series with James Belushi was based on Bruce Wagner's comic str
# Skipping duplicate: If I Were A Rich Man Was a big hit from which stage show?
#
# Processing triviamc_2883: Men Against the Sea and Pitcairn's Island were two sequels to what famous novel?...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# ⚠️ Unrecognized response format for triviamc_2883. Skipping.
# Skipping previously rejected: What is the only novel to top the best-seller lists for two consecutive years?
# Skipping duplicate: To whom did Helen Keller dedicate her autobiography, The Story of My Life?
# Skipping duplicate: "Complete this Biblical quotation: ""It is easier for a camel to go through the
# Skipping previously rejected: What was Truman Capote's last name before he was adopted by his stepfather?
# Skipping previously rejected: What book knocked Henry Kissinger's White house Years out of first place on the
# Skipping duplicate: In Lewis Carroll's poem The Hunting of the Snark, what did the elusive, troubles
# Skipping duplicate: In what state was playwright Tennessee Williams born?
# Skipping duplicate: Who was the only Englishman to become Pope?
# Skipping duplicate: In the Bible, who did the sun and moon stand still before?
# Skipping duplicate: What Michelle Pfeiffer movie got a boost from the Coolio song Gangsta's Paradise
# Skipping duplicate: In the Bible, who saw the handwriting on the wall?
# Skipping duplicate: What comic strip character was named after heavyweight boxing champion James J.
# Skipping duplicate: What was President Gerald Ford's middle name?
# Skipping duplicate: Who recorded the When Harry Met Sally soundtrack?
# Skipping duplicate: Art Garfunkel trained for which profession although he didn't qualify?
# Skipping duplicate: Who was the last inmate of Spandau jail in Berlin?
# Skipping previously rejected: What was Eddie Murphy's first movie?
# Skipping duplicate: In the 80s who wrote the novel Empire of The Sun?
# Skipping duplicate: Kagoshima international airport is in which country?
# Skipping duplicate: In which sport could the Pacers take on the Pistons?
# Skipping duplicate: Kim Carnes' nine weeks at No 1 with Bette Davis Eyes was interrupted for one wee
# Skipping duplicate: Where in Canada is the Lion's Gate bridge?
# Skipping duplicate: What was Walter Matthau's first movie?
# Skipping duplicate: Otis Barton was a pioneer in exploring where?
# Skipping duplicate: Where in England was actor Nigel Hawthorne born?
# Skipping duplicate: What would Kevin Scale have been called if it had adopted the originator's first
# Skipping duplicate: What mythological beast has the head of a man, the body of a lion, and the tail
# Skipping duplicate: In Greek mythology, who were Arges, Brontes and Steropes?
# Skipping duplicate: In Greek mythology, what were the names of Oedipus's parents?
# Skipping duplicate: Which musician founded the Red Hot Peppers?
# Skipping previously rejected: Where did the Shinning Path terrorists operate?
# Skipping duplicate: How old was Jimi Hendrix when he died?
# Skipping previously rejected: Which Brit broke the land speed record in 1990 in Thrust 2?
# Skipping duplicate: In which state was Gene Vincent born?
# Skipping duplicate: How was the European Recovery Program in the 1940s more commonly known?
# Skipping duplicate: Brandon Lee died during the making of which movie?
# Skipping duplicate: Who had a 70s No 1 hit with Let's Do It Again?
# Skipping duplicate: Who had a Too Legit To Quit Tour?
# Skipping duplicate: "According to Rudyard Kipling what were the ""two imposters"" to meet and treat
# Skipping previously rejected: Who is the most successful UK solo artist in the USA?
# Skipping duplicate: Where was horse racing's Breeder's Cup held in 1987?
# Skipping duplicate: Which country does the airline TAAG come from?
# Skipping duplicate: Which US No 1 single came from Diana Ross's platinum album Diana?
# Skipping duplicate: River Phoenix died during the making of which movie?
# Skipping duplicate: Which artist David was born in Bradford UK?
# Skipping duplicate: What is Mel Gibson's middle name?
# Skipping duplicate: Richard Daley was mayor of which city for 21 years?
# Skipping duplicate: "In which movie did Garbo say, ""I want to be alone""."
# Skipping duplicate: Robert Kirkpatrick of California grew the world's biggest what?
# Skipping duplicate: What is Osbert Lancaster best known for producing?
# Skipping duplicate: Who was the defending champion when Martina Navratilova first won Wimbledon sing
# Skipping duplicate: Who was the first US-born winner of golf's British Open?
# Skipping duplicate: In which country is the Sky Train Rail bridge?
# Skipping duplicate: What was the Paramount Film Company originally called?
# Skipping duplicate: Which founder of the company Triad was accused by the USA of receiving bribes?
# Skipping duplicate: Who was the first person after Scott to reach the South Pole overland?
# Skipping duplicate: Which journalist first told the world about the My Lai massacre?
# Skipping duplicate: What is the name of Terence and Shirley Conran's dress designer son?
# Skipping duplicate: Which drink did The Spice Girls promote?
# Skipping duplicate: Who was the youngest brother in the Beach Boys?
# Skipping duplicate: Which actress was called by the US Senate a 'powerful force of evil' when she le
# Skipping duplicate: Who first hosted Family Feud?
# Skipping previously rejected: What did the Lone Ranger's title Kemo Sabe mean in Apache?
# Skipping duplicate: Who or what was Gentle Ben in the 60s TV series?
# Skipping duplicate: Which 70s show was based on the British show Till Death Us Do Part?
# Skipping duplicate: On what date in 1969 did Neil Armstrong first set foot on the Moon?
# Skipping duplicate: Bandar Seri Begawan International airport is in which country?
# Skipping duplicate: What was the profession of Paul Strand (1890 - 1976)?
# Skipping duplicate: "Which supermodel said, ""I look very scary in the mornings?"
# Skipping previously rejected: Who wrote the song MacArthur Park?
# Skipping duplicate: Who had a 60s No 1 with Downtown?
# Skipping duplicate: Who was born first, Kiefer Sutherland or Christian Slater?
# Skipping duplicate: To the nearest two, how many tennis Grand Slam titles did Jimmy Connors win?
# Skipping duplicate: Who was the Georgia Peach?
# Skipping previously rejected: Who set fire to his guitar at the Monterey Pop festival in 19676?
# Skipping duplicate: Della Street was whose secretary?
# Skipping duplicate: In music, who was Sweet and Innocent and Too Young?
# Skipping duplicate: Who is featured on Puff Daddy's Can't Hold Me Down?
# Skipping duplicate: What had Edmond Hillary worked at before taking up mountain climbing?
# Skipping duplicate: In which American state is the Isabella Stewart Gardner Museum?
# Skipping duplicate: Benina international airport is in which country?
# Skipping duplicate: In 1986, which TV station sponsored the world's biggest wine tasting?
# Skipping duplicate: To a thousand, what is the area of Illinois in square miles?
# Skipping previously rejected: Beloved in 1999 was whose first movie since The Color Purple in 1985?
# Skipping previously rejected: Which Star Trek star directed Three Men and a Baby?
# Skipping duplicate: Which sitcom star appeared on the big screening The Object of My Affection?
# Skipping duplicate: "Which character did Julia ""Roberts play in Steven Spielberg's Hook?"
# Skipping duplicate: Which US president did Anthony Hopkins play in a film whose title was simply his
# Skipping duplicate: Which movie was a biopic about the life of David Helfgott?
# Skipping duplicate: Which film director guested as the FBI Director in The Silence of the Lambs?
# Skipping duplicate: In which sci fi classic did the space ship Nostromo first appear?
# Skipping duplicate: Nigel Hawthorne was Oscar nominated for The Madness of which King?
# Skipping duplicate: Which Swedish actress won the Best Supporting Actress Oscar for Murder on the Or
# Skipping duplicate: Which Oscar-nominated film had You Sexy Thing as its theme song?
# Skipping duplicate: Which Joan's career revived in Whatever Happened to Baby Jane?
# Skipping duplicate: Which much-loved actor won the Best Actor Oscar for The Philadelphia Story?
# Skipping duplicate: Which legendary dancer was Oscar-nominated for The Towering Inferno?
# Skipping duplicate: What was the name of the brothel in The Best Little Whorehouse in Texas?
# Skipping duplicate: Who was the male star of the movie The Man of La Mancha?
# Skipping duplicate: What relation is Joey Richardson to Vanessa Redgrave?
# Skipping duplicate: Melanie Molitor is the mom of which tennis world NO 1?
# Skipping duplicate: Marc Dutroux hit the headlines over a 'house of horrors' in which country?
# Skipping duplicate: On which date in 1945 did Hitler take cyanide then shoot himself?
# Skipping duplicate: How old would Elvis Presley have been had he lived to the end of the 20th centur
# Skipping previously rejected: In which river is the Boulder Dam?
# Skipping duplicate: Which sports event was first held at Worcester, Massachusetts in 1927?
# Skipping duplicate: In which European city is the Belvederen Gallery?
# Skipping duplicate: How old was Woody Herman when he founded his own orchestra?
# Skipping duplicate: For which movie did Katharine Hepburn win her second Oscar?
# Skipping duplicate: Who had a 60s No 1 hit with This Diamond Ring?
# Skipping duplicate: The world was first aware of the Chernobyl disaster after detectors were trigger
# Skipping duplicate: In which country was the first permanent bungee jumping site situated?
# Skipping previously rejected: Who succeeded Brezhnev as Soviet premier?
# Skipping duplicate: In the late 60s Owen Finlay MacLaren pioneered what useful item for parents of s
# Skipping duplicate: In which city's shipyard was Solidarity set up?
# Skipping duplicate: What was the first spacecraft to land on another planet?
# Skipping duplicate: Which female singer was born on exactly the same day as impressionist Rich Littl
# Skipping duplicate: What is Harrison Ford's real name?
# Skipping duplicate: Who's home runs record did Mark McGwire break in the 1998 season?
# Skipping duplicate: What were Joe DiMaggio's two baseball-playing brothers called?
# Skipping duplicate: Who won baseball's first World Series of the 80s?
# Skipping duplicate: What was Pete Sampras seeded when he won his first US Open?
# Skipping previously rejected: "Which boxer famously said,"" If I can't beat this bum take my name off the reco
# Skipping previously rejected: Where did Jonathan Edwards set his 1995 triple jump world record?
# Skipping duplicate: In baseball, where do the Orioles come from?
# Skipping duplicate: The Naismith Award is presented in which sport?
# Skipping duplicate: Which cartoon and film character is the nickname of super athlete Michael Johnso
# Skipping duplicate: For which team did Babe Ruth blast his last Major League home run?
# Skipping duplicate: How old would Bobby Kennedy have been had he lived to the end of the 20th centur
# Skipping duplicate: What was Warren Beatty's first movie?
# Skipping duplicate: Where does Roseanne have a tattoo of a pink rose?
# Skipping duplicate: Which future Hollywood star got her break as Wonder Girl, Wonder Woman's sister
# Skipping duplicate: Mickey Braddock in the 50s series Circus Boy found fame with which surname in wh
# Skipping previously rejected: Which war veteran was Director of News & Special Events for ABC before find fame
# Skipping previously rejected: What US sitcom was the first exported to Britain?
# Skipping duplicate: In Hanna and Barbera's TV cartoons base on The Addams Family who was the voice o
# Skipping duplicate: Who was the only female victim to be killed off in the opening credit sequence i
# Skipping duplicate: In 1990 who faced banners saying Goodbye Pineapple Face?
# Skipping duplicate: How much did Clint Eastwood receive per month for his duties as Mayor of Carmel?
# Skipping previously rejected: Which US president won the Nobel Peace Prize in 1920?
# Skipping duplicate: Who beat Tim Henman in his first Wimbledon singles semifinal?
# Skipping duplicate: What relation was Flo Jo to Jackie Joyner Kersee?
# Skipping duplicate: How long was swimmer Michelle Smith-de Bruin banned for attempting to manipulate
# Skipping duplicate: Yuan Yuan was caught carrying drugs for which Chinese team?
# Skipping duplicate: Which grand slam did Pete Sampras not win in the 20th century?
# Skipping duplicate: In which events did Gert Fredriksson win six Olympic gold medals?
# Skipping duplicate: How many of his 45 races did Mike Hawthorn, a former Formula One motor racing wo
# Skipping duplicate: On the Internet what is Spam?
# Skipping duplicate: In which country did the Internet start?
# Skipping duplicate: In which year was the Juilliard School founded in New York?
# Skipping duplicate: Where was horse racing's Breeders' Cup held in 1989?
# Skipping duplicate: Who wrote My Life and Loves in 1926, originally banned in the US?
# Skipping duplicate: What was Blondie's last UK No 1 of the 80s?
# Skipping duplicate: If it is 3 a.m. in Nevada, what time is it in Montana?
# Skipping duplicate: In baseball, where do the Royals come from?
# Skipping previously rejected: What is the largest city in Ohio?
# Skipping duplicate: In which decade of the 20th century was Anne Bancroft born?
# Skipping duplicate: The Suez Canal connects the Mediterranean Sea to which other Sea?
# Skipping duplicate: Vehicles from which country use the international registration letter E?
# Skipping duplicate: Which rock star did Cindy Crawford name her first son after?
# Skipping duplicate: Sun Yat Sen overthrew the emperor in which country establishing a republic after
# Skipping duplicate: Who designed the dress which made the most at Diana's dress auction?
# Skipping duplicate: Which Palestinian co-founded al Fatah in 1957?
# Skipping duplicate: In which country was Earl Spencer's acrimonious divorce settlement heard?
# Skipping duplicate: In which North African country was Mohammed Al-Fayed, owner of Harrods departmen
# Skipping duplicate: Aung San Suu Kyi is a controversial leader in which country?
# Skipping duplicate: Which of the founders of United Artists had the last name nearest the beginning
# Skipping duplicate: In La Cage Aux Folles, what was La Cage Aux Folles?
# Skipping duplicate: Where was the Fiddler in the musical's title?
# Skipping duplicate: South Pacific was set during which war?
# Skipping duplicate: What percentage of the earth's surface is covered by Europe?
# Skipping duplicate: Which European town gave its name to a Treaty which symbolizes closer economic l
# Skipping duplicate: Which home of champagne in France was also where the German High Command surrend
# Skipping previously rejected: Which was the first European city this century to open an underground railway sy
# Skipping duplicate: Who first drew Mickey Mouse when ?Disney first supplied the voice?
# Skipping duplicate: Which actress wrote the novel The Last of the Really Great Whangdoodles?
# Skipping duplicate: Who was the star of the film based on the record Harper Valley PTA by Jeannie C
# Skipping duplicate: What color golf balls are used on the golf course in Antarctica?
# Skipping previously rejected: Throughout the 80s and 90s Phil Collins recorded on which record label?
# Skipping previously rejected: On which label did Chuck Berry record in the 1950s and 1960s?
# Skipping previously rejected: Which museum has the highest-funded art gallery?
# Skipping duplicate: What was the name of Michael Jackson's second wife?
# Skipping duplicate: Which US city was named after a British Prime Minister?
# Skipping duplicate: "Who said, To err is human but it feels divine?"""
# Skipping duplicate: Which singer had a big 60s No 1 with Roses Are Red?
# Skipping duplicate: What are the international registration letters of a vehicle from Iceland?
# Skipping duplicate: Where was the American venue of the Live Aid concert?
# Skipping duplicate: Which was the longest moon landing?
# Skipping previously rejected: Who had the most expensive presidential inauguration ceremony of the 20th centur
# Skipping previously rejected: Who became Israel's head of state in 1993?
# Skipping duplicate: In WWII, who was the head of the Nazi party's security service?
# Skipping duplicate: Which President of the Philippines was deposed in 1986?
# Skipping duplicate: What kind of disaster claimed some 100,000 lives in Armenia in 1988?
# Skipping duplicate: Which state on the Gulf of Mexico is nearest the end of the alphabet?
# Skipping duplicate: To ten thousand square miles, what is the area of Michigan?
# Skipping duplicate: Truax Field international airport is in which US state?
# Skipping duplicate: In what month was the attack on Pearl Harbor?
# Skipping duplicate: Who did Dr. Crippen murder?
# Skipping duplicate: In the 1904 Olympics, how many of the 23 track and field titles were won by Amer
# Skipping duplicate: The Black Hills lie between which two rivers?
# Skipping previously rejected: In what year was the first in-flight movie shown on an internal flight in the US
# Skipping previously rejected: In which city was John Lennon murdered?
# Skipping duplicate: How was President Kennedy assassinated?
# Skipping duplicate: Which caped crusader operated in Gotham City?
# Skipping duplicate: Who did Jack Ruby shoot in November 1963?
# Skipping duplicate: Who was the first American to travel faster than the speed of sound?
# Skipping duplicate: Who was the first US president Barbara Walters interviewed?
# Skipping duplicate: Which orchestral conductor was married to one of the subjects of the film Hillar
# Skipping duplicate: Which writer and politician became Lord Tweedsmuir?
# Skipping duplicate: In what year was the first Tarzan novel published?
# Skipping duplicate: In which country were motorized ambulances first used?
# Skipping duplicate: In which city was the first Model T produced outside the USA?
# Skipping duplicate: What is the Pacific terminus of the Trans Siberian Railway?
# Skipping previously rejected: What appears in the middle of the Rwandan flag?
# Skipping duplicate: What is the name of the mountain pass which lies between Pakistan and Afghanista
# Skipping duplicate: What is the name of the group of 1,196 islands in the North Indian Ocean, none b
# Skipping duplicate: Which Syrian city is said to be the oldest continually inhabited city in the wor
# Skipping duplicate: Who was king of France at the time of the French Revolution?
# Skipping duplicate: What is the principal language of Bulgaria?
# Skipping duplicate: What is the name of the cathedral in Red Square, Moscow?
# Skipping duplicate: Which country is known to its people as Suomen Tasavalta?
# Skipping duplicate: Which crusade was led by Philip II Augustus of France and Richard I of England?
# Skipping duplicate: In which Netherlands city does the United Nations International Court of Justice
# Skipping duplicate: In which battle did Harold II, the last Saxon king, lose his life?
# Skipping duplicate: Who proclaimed the People's Republic of China in 1949?
# Skipping duplicate: Which wife of Henry VIII had already married twice before she became queen, and
# Skipping duplicate: In which country is the castle that gives the Habsburg dynasty its name?
# Skipping duplicate: Who were the victors of the Battle of Austerlitz?
# Skipping previously rejected: In which parliament has the UK 87 seats for members who are elected for a five0-
# Skipping duplicate: What was the former name of the British Green Party?
# Skipping duplicate: Who were the two prime ministers of Britain during World War II?
# Skipping duplicate: "What is the more common name of the ""simple plurality"" system of voting?"
# Skipping duplicate: What word for unthinking patriotism is derived from the name of one of Napoleon'
# Skipping duplicate: Which builder of steam engines formed a successful partnership with Matthew Boul
# Skipping duplicate: What was the nickname of the French singer Edith Piaf?
# Skipping duplicate: Whose birthday is celebrated by a public holiday on the third Monday in January
# Skipping duplicate: What type of coal is brown and fibrous?
# Skipping duplicate: What raw material is used for making glass?
# Skipping duplicate: What kind of an organism is a truffle?
# Skipping duplicate: What is the name of the strong material found in plant cell walls?
# Skipping duplicate: What name is given to the change of state from liquid to gas?
# Skipping previously rejected: Which branch of science has four fundamental principles: addition, subtraction,
# Skipping duplicate: What is the force that opposes the relative motion of two bodies that are in con
# Skipping duplicate: What is the fastest animal on two legs?
# Skipping duplicate: What is the green pigment used by plants to trap sunlight?
# Skipping duplicate: What id the name given to the study of birds?
# Skipping duplicate: Of which reptile are there only two species, one living in the Mississippi and t
# Skipping duplicate: What type of seaweed grows up to 100 meters in length, and is farmed for its alg
# Skipping duplicate: Where in a vertebrate would you find the protein myoglobin?
# Skipping duplicate: What is the most abundant substance in the plant kingdom, which no mammal produc
# Skipping duplicate: Which family of insects has species named 'drivers', 'weavers', 'and even indivi
# Skipping duplicate: What name is given to the study of animal behavior?
# Skipping duplicate: Mosses are classified as belonging to which part of the plant kingdom?
# Skipping duplicate: Which rodent rears its young, called kittens, in a nest called a drey?
# Skipping duplicate: What has a central vein called a midrib?
# Skipping duplicate: Which mammal constructs a lodge in which to store food, rear young, and pass the
# Skipping duplicate: What is the generic word for plants that grow in water or water-logged condition
# Skipping duplicate: Which teeth are the third molars, and are always the last to0 erupt?
# Skipping duplicate: What is secreted by the pancreas to regulate blood sugar levels?
# Skipping duplicate: How many chambers has the heart?
# Skipping duplicate: What is the name of the large buttock and thigh muscle?
# Skipping duplicate: When the egg is released from the ovary, what is left behind?
# Skipping duplicate: What is the scientific name for the heart's pacemaker?
# Skipping duplicate: Which hormone helps control ovulation?
# Skipping duplicate: What is the second most common gas in the atmosphere?
# Skipping duplicate: What is the term for nutrient enrichment of lakes?
# Skipping previously rejected: Five-legged creatures have damaged which 1250 mile long wonder of the world?
# Skipping duplicate: Which radioactive substance sometimes occurs naturally in spring water?
# Skipping duplicate: What is the approximate circumference of the earth?
# Skipping duplicate: What is the name of the organization which controls whaling?
# Skipping previously rejected: How large is the area seated within the project BioSphere 2?
# Skipping duplicate: Which common mineral is used to make casts, moulds, blackboard chalk and plaster
# Skipping duplicate: What name was given to the invisible material once thought to occupy all space?
# Skipping duplicate: What is the name of the theory that the universe appears the same wherever and w
# Skipping duplicate: From which areas of space can there be no escape?
# Skipping duplicate: Who was the first man to walk on the Moon?
# Skipping duplicate: Proteus and Nereid are moons of which planet?
# Skipping duplicate: What is the Milky Way?
# Skipping duplicate: Which force is nothing more than the bending of space and time?
# Skipping duplicate: Which star is as bright as 23 Suns, and is orbited by the Pup?
# Skipping duplicate: What are the three primary colours of light?
# Skipping duplicate: Which three South American countries does the Equator cross?
# Skipping duplicate: In what film did Oprah Winfrey make her big screen acting debut?
# Skipping duplicate: What is the second lightest chemical element?
# Skipping previously rejected: Used in mathematics, what is the value of Pi to three decimal places?
# Skipping duplicate: What colour is the number 10 on the door of 10 Downing Street? White, Yellow or
# Skipping duplicate: What was advertised with Eva Herzagovia using the slogan hello boys?
# Skipping duplicate: What number in Bingo is sometimes referred to as Heinz varieties?
# Skipping previously rejected: The largest ever teddy bears picnic was held in Dublin in 1995. How many bears w
# Skipping duplicate: As at March 2001, who holds the record for scoring the most league goals for the
# Skipping duplicate: How many verses make up the national anthem God Save The Queen?
# Skipping duplicate: What colour is the cross on the national flag of Switzerland?
# Skipping duplicate: Who was the American President when the Berlin Wall was constructed?
# Skipping duplicate: What is the minimum number of darts a person needs to throw to complete a leg fr
# Skipping previously rejected: What was the first British football team to win the European Cup?
# Skipping previously rejected: What is the most popular natural attraction in Alaska?
# Skipping duplicate: What type of acid is extracted from the juice of lemons, oranges, limes, and gra
# Skipping previously rejected: What is the difference between a frog and a toad?
# Skipping duplicate: How many pieces are there in a standard set of dominoes?
# Skipping duplicate: What is the acronym for the agency which provides co-operation between police fo
# Skipping previously rejected: As at the year 2001, what are the only two films to receive 14 Oscar nominations
# Skipping previously rejected: What were Benjy and Laska, which were sent into space in 1958?
# Skipping duplicate: In what year in the 20th century was the Miss World contest held for the first t
# Skipping previously rejected: In which year was the Encyclopedia Britannica first published?
# Skipping previously rejected: On the London Underground, which is the only line to connect at some point with
# Skipping duplicate: In 1981, what became the first ever music video to be shown on MTV?
# Skipping duplicate: Who wrote The Importance Of Being Earnest?
# Skipping previously rejected: Thomas Edison, who invented the lightbulb, was afraid of the dark?
# Skipping previously rejected: Taphephobia is the fear of losing your teeth?
# Skipping duplicate: The letter t is the second most common letter used in the English language?
# Skipping duplicate: The invention of what in 1867, made Alfred Nobel famous?
# Skipping previously rejected: What is the most populated city in America?
# Skipping duplicate: What is the only letter of the alphabet which does not appear in any of the name
# Skipping duplicate: In 1931, what became the first ever televised sports event?
# Skipping duplicate: What was the Spice Girls' debut single called?
# Skipping duplicate: What are the only two musical notes which have no flats?
# Skipping previously rejected: From which country do French fries originate? France, Belgium or Switzerland?
# Skipping duplicate: For what novel did J. K. Rowling win the 1999 Whitbread Children's book of the y
# Skipping duplicate: Mary has a large bedroom and the only light switch is on the wall approximately
# Skipping previously rejected: What is the longest word can be typed using only the top row of letters on a typ
# Skipping previously rejected: A man lives on the 20th floor of a block of flats. If it is a rainy day, he gets
# Skipping previously rejected: What is the only football league team in Britain which doesn't have any of the l
# Skipping duplicate: In which city would you find O'Hare International Airport?
# Skipping duplicate: Which Asian country was once called Siam?
# Skipping duplicate: Which three countries does Luxembourg border?
# Skipping duplicate: What are the names of Donald Duck's three nephews?
# Skipping duplicate: In which 1993 film does a boy called Jonah write to a woman called Annie, asking
# Skipping duplicate: Who had a top ten hit in 1988 with Valentine?
# Skipping duplicate: What is the second most common word in written English?
# Skipping duplicate: In which arcade game, would you find ghosts called Inky, Pinky, Blinky and Clyde
# Skipping duplicate: More commonly known as the thigh bone, what is the medical name for the longest
# Skipping duplicate: What word is used to describe someone who is neither left or right handed, but c
# Skipping duplicate: Which cult film, starring Harrison Ford, was based on the story Do Androids Drea
# Skipping duplicate: Which ITV magazine style show ran from 1968 to 1980 and featured presenters incl
# Skipping duplicate: Which type of animal was Robin Hood in the Disney cartoon film 'Robin Hood'?
# Skipping duplicate: Who provided the voice for Bob The Builder on his number one hit Can We Fix It?
# Skipping duplicate: Which actor received 4 million dollars for his 10 minutes on screen in the film
# Skipping duplicate: Who directed the films Thelma and Louise, Hannibal and Black Hawk Down?
# Skipping duplicate: Which serial killer is the subject of the films A Study In Terror, Murder By Dec
# Skipping duplicate: In cricket, what is the score of 111 known as?
# Skipping duplicate: Yuppy Love, Danger UXD, The Frog's Legacy, Diamonds Are For Trevor?
# Skipping previously rejected: Batman Returns, Practical Magic, Dead Calm, The Peacemaker?
# Skipping duplicate: Who wrote the novels About A Boy, How To Be Good and High Fidelity?
# Skipping duplicate: With which game would you use a squidger, a circular disc between 25mm and 51 mm
# Skipping duplicate: The melody for which famous song was written by sisters and school teachers Patt
# Skipping duplicate: What is the most common pub name in the UK?
# Skipping previously rejected: What is the name of Kevin the teenager's friend played by Kathy Burke in a serie
# Skipping duplicate: What seven letter word, beginning with the letters 'Ra' is a palindrome?
# Skipping duplicate: Which fruit can go in the middle of the word aped to make a new word?
# Skipping duplicate: How many scottish football league teams names end in United?
# Skipping duplicate: Who had a top ten hit in the UK with Cupid in 1961?
# Skipping duplicate: Which 1999 Oscar winning film has a title which refers to a breed of rose and fe
# Skipping duplicate: The theme tune to which TV show starts with the line Stick a pony in me pocket?
# Skipping duplicate: What word is given to a point in tennis which has to be replayed?
# Skipping duplicate: Which three colours appear on the flag of the Republic of Ireland?
# Skipping duplicate: How many episodes of Prisoner: Cell Block H were made?
# Skipping duplicate: Who is the last English-born player to win the men's singles title at Wimbledon?
# Skipping duplicate: Which famous painter's surname was Harmenzoon van Rijn which translated as son o
# Skipping duplicate: In 1976, which gymnast scored 7 maximum scores of 10 as she won three gold medal
# Skipping previously rejected: In years and days, how old was Luigina Giavotti when she won a silver medal in g
# Skipping previously rejected: As at August 2004, who is Englands all time top goalscorer?
# Skipping duplicate: Which Eastenders actor has played the policeman Nick Rowan on TV?
# Skipping duplicate: What type of animal was Boris, the subject of a song by The Who?
# Skipping duplicate: Which brand of beer does Homer Simpson drink regularly?
# Skipping duplicate: From which animal does Haggis come?
# Skipping duplicate: In which country was Marie Curie born? Poland, Austria or Switzerland?
# Skipping duplicate: What is the most common blood type in humans? A, B or O?
# Skipping duplicate: Which P is the correct technical term for the art of making and displaying firew
# Skipping duplicate: Which King did Guy Fawkes attempt to kill with his gunpowder plot?
# Skipping previously rejected: Behind Band Aid's Do They Know It's Christmas which 1978 single is the second bi
# Skipping duplicate: In which film was the song White Christmas first sung?
# Skipping duplicate: Which Pop Idol had a number one hit in 2004 called All This Time?
# Skipping duplicate: Why did Jason Alexander from Louisiana hit the headlines in January 2004?
# Skipping duplicate: Which Channel 4 TV show's presenters included Mark Lamarr, Amanda De Cadenet and
# Skipping duplicate: What is the name of the device made of wood and horsehair that is used to play a
# Skipping duplicate: What colour is the bottom stripe on the U.S. flag?
# Skipping duplicate: What is the name given to the largest bee in a hive?
# Skipping duplicate: Who won the Ladies singles title at Wimbledon in 2004?
# Skipping duplicate: Which famous female character of TV and films was played by a male when she was
# Skipping duplicate: What is the alcoholic ingredient of Irish coffee?
# Skipping duplicate: In which year did St George die?
# Skipping duplicate: What are the names of the Four Horseman of the Apocalypse?
# Skipping duplicate: Who were the four different Snooker World Champions in the 1990s?
# Skipping duplicate: Who is the Vice-President for George W Bush?
# Skipping duplicate: Which film sees Clint Eastwood, Tommy Lee Jones, James Garner and Donald Sutherl
# Skipping duplicate: In a standard deck of cards, how many Kings have a moustache?
# Skipping duplicate: According to the film Gremlins, if you are looking after a Gremlin you should no
# Skipping duplicate: The Canary Islands are named after what animal?
# Skipping duplicate: In which capital city would you find Charles Bridge and Wenceslas Square?
# Skipping duplicate: What was the surname of the woman who was the inspiration behind the Rolling Sto
# Skipping duplicate: What is the final event in a decathlon?
# Skipping duplicate: Peter Simple, Jack Horner and Ben Nevis have all won which famous sporting event
# Skipping duplicate: What is the largest city in Turkey?
# Skipping duplicate: What are the names of the four US states which begin with the word 'New'?
# Skipping previously rejected: Who are the only two groups to have had 3 consecutive Christmas Number Ones in t
# Skipping previously rejected: By the end of the 17th series of Who Wants To Be A Millionaire in 2005, how many
# Skipping duplicate: Who bought Chelsea football club for £1 in 1982?
# Skipping duplicate: In 1998, which director's Oscar acceptance speech included the line I'm king of
# Skipping duplicate: What nationality was the painter Vincent Van Gogh?
# Skipping duplicate: Which film features the characters Sally Albright and Harry Burns?
# Skipping duplicate: In the world of film, what connects May Day, Jinx and Solitaire?
# Skipping duplicate: Which act won the Eurovision Song Contest for the United Kingdom singing Love Sh
# Skipping duplicate: Which four presidents heads are sculpted on Mount Rushmore?
# Skipping duplicate: Which English word comes from an old French word meaning sour wine?
# Skipping duplicate: Which team beat American Samoa 31-0 in a qualifying match for the 2002 World Cup
# Skipping duplicate: What was the name of Roland Rat's gerbil friend?
# Skipping duplicate: Which animal has the longest gestation period at around 22 months?
# Skipping duplicate: What name is given to the home of a beaver?
# Skipping duplicate: What name is given to a baby marsupial?
# Skipping duplicate: Who dated actress Elizabeth Hurley between 2000 and 2001 and denied he was the f
# Skipping duplicate: What type of animal is the star of the 2005 film Racing Stripes?
# Skipping duplicate: Author Dick Francis is famous for writing novels based around which sport?
# Skipping duplicate: Which Scottish newspaper features the Broons and Oor Wullie?
# Skipping duplicate: Which famous book features the character of Bob Cratchit?
# Skipping duplicate: Which act has had more Christmas number one singles than any other?
# Skipping duplicate: Which Christmas song includes the line It seems so long since I could say 'siste
# Skipping previously rejected: Which British footballer has the most number of International caps?
# Skipping duplicate: Who holds a trumpet on the album cover of Sgt. Pepper's Lonely Hearts Club Band
# Skipping duplicate: Which song begins with the line The taxman's taken all my dough?
# Skipping duplicate: What former X-Factor contestant had a top ten hit album called Picture Of You in
# Skipping duplicate: The Kray twins were convicted of the murder of George Cornell in the East End of
# Skipping duplicate: Who composed the musical theme for the Pink Panther?
# Skipping duplicate: Who was the cartoon adversary of Pixie and Dixie, who would often say I hate tho
# Skipping duplicate: Which actress married Dennis Quaid on Valentine's Day in 1991?
# Skipping duplicate: During Margaret Thatcher's years as Prime Minister, there were three Chancellors
# Skipping duplicate: Buddy Holly and the Big Bopper were two of the three musicians who died in a pla
# Skipping duplicate: Fruit, cricket and horseshoe are varieties of what type of animal?
# Skipping duplicate: Apart from being warm blooded and giving birth to live young, what do mammals pr
# Skipping previously rejected: Pleased it`s passed tea time
# Skipping duplicate: To which poet does Il Postino deliver mail?
# Skipping duplicate: Which scientist was Time magazine's "Person of the 20th Century"?
# Skipping duplicate: What was the nickname given to premiership footballer Neil Ruddock?
# Skipping duplicate: The Ducati is manufactured in which city and what country?
# Skipping duplicate: Wayne Rooney signed for Manchester United from which other Premiership Club?
# Skipping duplicate: The Yalu river forms a sort of natural border between China and which of its nei
# Skipping duplicate: Which stand-up comedian presents 8 Out Of 10 Cats and Distraction?
# Skipping previously rejected: Name the game show, presented by Leslie Grantham and Melinda Messenger, where co
# Skipping duplicate: Who presented Family Fortunes in the two years between Bob Monkhouse and Les Den
# Skipping duplicate: For what did Einstien gat Nobel prize in Physics?
# Skipping duplicate: Which planet has moons named after Shakespearean characters?
# Skipping duplicate: Who was part man, part machine, all cop and hailed from a futuristic Detroit?
# Skipping duplicate: Who dubbed Miss Piggy's singing voice in The Muppet Movie?
# Skipping duplicate: Who wrote the Bourne trilogy of books, made into movies starring Matt Damon?
# Skipping duplicate: The Bible tells of 3 wise men visiting Jesus after his birth, but in which of th
# Skipping duplicate: Athos and Porthos are two of the 3 musketeers, name the other one.
# Skipping duplicate: What is the name of the small fifth claw called on the side of a dog's foot ?
# Skipping duplicate: What is the name of the plastic bit on the end of shoelaces?
# Skipping duplicate: The river Danube flows into which sea?
# Skipping duplicate: Anna Nicole Smith was controversially married to which oil billionaire?
# Skipping duplicate: Wayne Rooney scored his first senior goal against which club?
# Skipping previously rejected: How meny times have Liverpool won the Europion Cup?
# Skipping duplicate: The Sign Of Four was a detective story written by which author?
# Skipping duplicate: Who was the author of 'The Old Curiosity Shop'?
# Skipping previously rejected: The River Danube runs through which three European capital cities?
# Skipping duplicate: In which sport or pastime can you see nose walking?
# Skipping previously rejected: In which occupation would you rotate the gog at the end of your nose?
# Skipping duplicate: What sport or pastime would you be playing if your balls were black and blue and
# Skipping duplicate: The age of the railway began in which year with the introduction of the Liverpoo
# Skipping duplicate: Who played Frankenstein in the 1994 film of the same name?
# Skipping previously rejected: What won't a cockroach eat?
# Skipping previously rejected: Who was the first person to sell one million records?
# Skipping duplicate: In Greek mythology, where do righteous souls go after death?
# Skipping duplicate: What is the scientific name given to tea?
# Skipping duplicate: In the 1999 film Stuart Little, who plays the part of Mrs Eleanor Little?
# Skipping previously rejected: Suger Mice was a 1987 single for which British rock band?
# Skipping duplicate: In which decade were ZIP codes introduced in the USA?
# Skipping duplicate: What are the shape-shifting foxes of the Japanese folklore?
# Skipping duplicate: In Greek mythology who was the twin of Polydeuces?
# Skipping duplicate: Which film features the Dawes Tomes Mousley Grubbs Fidelity Fiduciary Bank?
# Skipping duplicate: What is Robin Williams character called in Good Morning Vietnam?
# Skipping duplicate: Who plays Cruella de Vil in the 1996 live action version of 101 Dalmations?
# Skipping duplicate: Who stars in the 2008 movie Seven Pounds?
# Skipping duplicate: Marilyn Monroe starred in the Seven Year Itch. Who directed it?
# Skipping duplicate: On Red Nose Day 2001 who won Celebrity Big Brother?
# Skipping duplicate: Excluding Lady Jane Grey, who were the five monarchs of the House of Tudor?
# Skipping duplicate: What are the four classical elements that make up our world?
# Skipping duplicate: What is the name of the London Underground station in EastEnders?
# Skipping duplicate: How many runs did Donald Bradman score in his last ever test match innings?
# Skipping duplicate: Nicknamed the cannibal, who is the only rider to have won all three jerseys in t
# Skipping duplicate: Whose arch nemisis is the Red Skull?
# Skipping duplicate: By what name is comic book villain Oswald Chesterfield Cobblepot better known?
# Skipping duplicate: First appearing on TV in 1967, which detective solved all of his crimes sitting
# Skipping duplicate: How many times was Wyatt Earp shot?
# Skipping duplicate: Which famous cowboy was created by George W. Trendle?
# Skipping previously rejected: The pub with the longest name in the UK has how many letters in it? 55, 75 or 95
# Skipping duplicate: Which movie starred Michael Caine as a murderous transvestite psychiatrist?
# Skipping previously rejected: What is the brightest star in our celestial sphere?
# Skipping duplicate: In 1961, who famously scored six goals in a match but still ended up on the losi
# Skipping duplicate: Which economist wrote The Wealth Of Nations?
# Skipping duplicate: Macbeth belonged to which royal house or dynasty?
# Skipping duplicate: Was James II known as: James The Bald, Fiery Face, or The Red King?
# Skipping duplicate: In Harry Potter And The Goblet Of Fire, which dragon did Harry have to defeat?
# Skipping duplicate: What is the full name of the train robber played by Phil Collins in a 1988 movie
# Skipping duplicate: Tony Hadley was the lead singer with which 1980s new romantic band?
# Skipping duplicate: What was the surname of the butler played by Gordon Jackson in Upstairs Downstai
# Skipping duplicate: Which Jackson appeared in Celebrity Big Brother in January 2009?
# Skipping duplicate: Who was the seventh president of the United States?
# Skipping duplicate: In which country are the Angel Falls, the highest waterfall in the world?
# Skipping duplicate: The 1955 comedy movie We're No Angels centred on three escaped convicts. Peter U
# Skipping duplicate: Who played King Arthur in the 1967 musical film Camelot?
# Skipping duplicate: Which country grows the largest number of mangoes?
# Skipping duplicate: Ecuador has a border with Peru and which other country ?
# Skipping duplicate: In 2009, who was convicted of the murder of Lana Clarkson?
# Skipping duplicate: The left side of the heart pumps blood to all parts of the body, but the right s
# Skipping duplicate: Which cartoon character lives in a pineapple under the sea?
# Skipping duplicate: Which serial killer hanged himself in Wakefield Prison in January 2004, four yea
# Skipping duplicate: What public school did the Duke of Edinburgh and Prince Charles attend?
# Skipping duplicate: As a result of finishing fifth in the 1980 Winter Olympics figure skating compet
#
# Processing triviamc_2884: If it was Phil Mickelson in 2006, Zach Johnson in 2007, and Trevor Immelman in 2...
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# ⚠️ Unrecognized response format for triviamc_2884. Skipping.
# Skipping duplicate: Which British comedy actor has a refuse tip named after him in New Zealand, afte
# Skipping duplicate: Red Stripe lager comes from which country?
# Skipping duplicate: Which architect was known as the Wizard of the Dome?
# Skipping duplicate: What is the name of the Salvador Dali painting that shows clocks oozing over a l
# Skipping duplicate: In what year did Edward Vlll abdicate?
# Skipping duplicate: Which well known couple live at Bagshot Park in Surrey?
# Skipping duplicate: Which notorious murderer lived at 10 Rillington Place?
# Skipping duplicate: Who killed Lee harvey Oswald?
# Skipping duplicate: Who killed Robert F Kennedy?
# Skipping duplicate: Who killed Jean Paul Marat?
# Skipping duplicate: What was the name of the kangaroo often mistaken by Sylvester the cat to be a gi
# ...
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2900: In which book of the Old Testament does the destruction of the walls of Jericho ...
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2901: In which northern British town can you find a large shopping centre called Hound...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2902: Which modern day country was known until 1981 as British Honduras?...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2903: Which ex-politician, now aged 80, had the nickname 'The Chingford Skinhead'...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# ⚠️ Flagged triviamc_2903: The age reference "now aged 80" makes this question time-sensitive and potentially outdated. Norman Tebbit was born in 1931, so he would have been 80 around 2011. As of 2024, he would be 93 if still living. The question needs to specify a date or remove the age reference to remain factually accurate.
#
# Processing triviamc_2904: What is the usual colour of the drink Grenadine?...
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Thread execution error: RateLimitError: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# Error in llm processing: Error code: 429 - {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'anthropic/claude-opus-4.1 is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Google'}}, 'user_id': 'user_2olc3UxrHvMROEYTU2RrqXohqvn'}
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2905: Which Englsih football club play home matches at the Sports Direct Arena?...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# ⚠️ Flagged triviamc_2905: The Sports Direct Arena was the temporary name of Newcastle United's stadium from 2011-2012. The stadium is now called St James' Park (having reverted to its traditional name). The question uses outdated information and would be misleading to current trivia players.
#
# Processing triviamc_2906: Which film of 2005, directed by Sam Mendes, is based on former marine and author...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# Checkpoint: 10 accepted questions so far.
#
# Processing triviamc_2907: The name of which French newspaper translates as The World?...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2908: Who won the Oscar for Best Film Director for the film Silence of the Lambs?...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2909: "Which famous speech of 1968 began with the words ""The supreme function of stat...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
# ⚠️ Flagged triviamc_2909: The quoted opening line is incorrect. Enoch Powell's "Rivers of Blood" speech from April 20, 1968, actually began with "The supreme function of statesmanship is to provide against preventable evils" (not "preventative evils"). The word should be "preventable" not "preventative."
#
# Processing triviamc_2910: """The Black Gang"" in 1922 and ""Temple Tower"" in 1929 were books that feature...
# In model_call, provider=OpenRouter, attempt=1
# Provider that responded: Google
#
# Processing triviamc_2911: The traditional Royal Navy game of Uckers, invented in the late 18th century was...
# In model_call, provider=OpenRouter, attempt=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 178
#     176 for attempt in range(max_retries):
#     177     try:
# --> 178         response, _, _ = trivia_judge._get_llm_answer(
#     179             options=None,
#     180             q_text=unified_prompt.format(
#     181                 question=question_text,
#     182                 possible_answers=possible_answers,
#     183             ),
#     184             message_history=[],
#     185             keep_appending=False,
#     186             setup_text=trivia_sysprompt,
#     187             MAX_TOKENS=None,
#     188             temp=0.7,
#     189         )
#     191         if response:
#     192             break  # Success, exit retry loop
#
# File ~/dev/code/llm-metacognition/base_game_class.py:487, in BaseGameClass._get_llm_answer(self, options, q_text, message_history, keep_appending, setup_text, MAX_TOKENS, temp, accept_any, top_p, top_k)
#     485         raise ValueError(f"Unsupported provider: {self.provider}")
#     486 try:
# --> 487     resp, token_probs = self._call_with_timeout(model_call, timeout=150)
#     488 except TimeoutError:
#     489     self._log(f"Timeout on attempt {callctr+1}, retrying…")
#
# File ~/dev/code/llm-metacognition/base_game_class.py:133, in BaseGameClass._call_with_timeout(self, fn, timeout)
#     129 future = executor.submit(fn)
#     131 try:
#     132     # Wait for the result with timeout
# --> 133     result = future.result(timeout=timeout)
#     134     # Only if we get here, shutdown with wait=True is safe
#     135     executor.shutdown(wait=True)
#
# File ~/miniconda3/envs/spar/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/miniconda3/envs/spar/lib/python3.11/threading.py:331, in Condition.wait(self, timeout)
#     329 else:
#     330     if timeout > 0:
# --> 331         gotit = waiter.acquire(True, timeout)
#     332     else:
#     333         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Provider that responded: Google

# %%
import json
f1 = "./delegate_game_logs/claude-3-5-sonnet-20241022_GPSA_50_450_team0.7_temp0.0_1749479584_game_data_evaluated.json"
f2 = "./delegate_game_logs/claude-3-5-sonnet-20241022_GPSA_50_450_nohistory_summary_team0.5_temp0.0_1749559243_game_data_evaluated.json"
with open(f1, 'r', encoding='utf-8') as f:
    game_data_hist = json.load(f)
with open(f2, 'r', encoding='utf-8') as f:
    game_data_nohist = json.load(f)

diff_del_list = []
diff_choice_list = []
for trial in game_data_hist['results']:
    qid = trial['question_id']
    for trial_nohist in game_data_nohist['results']:
        if trial_nohist['question_id'] == qid:
            if trial['delegation_choice'] != trial_nohist['delegation_choice']:
                diff_del_list.append((trial, trial_nohist))
            elif (trial['delegation_choice']=="Self" and trial['subject_correct'] != trial_nohist['subject_correct']):
                diff_choice_list.append((trial, trial_nohist))
            break
print(f"Found {len(diff_del_list)} trials with delegation differences between history and no history versions.")
print(f"Found {len(diff_choice_list)} trials with choice differences between history and no history versions.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 f1 = "./delegate_game_logs/claude-3-5-sonnet-20241022_GPSA_50_450_team0.7_temp0.0_1749479584_game_data_evaluated.json"
#       3 f2 = "./delegate_game_logs/claude-3-5-sonnet-20241022_GPSA_50_450_nohistory_summary_team0.5_temp0.0_1749559243_game_data_evaluated.json"
# ----> 4 with open(f1, 'r', encoding='utf-8') as f:
#       5     game_data_hist = json.load(f)
#       6 with open(f2, 'r', encoding='utf-8') as f:
#
# File ~/miniconda3/envs/spar/lib/python3.11/site-packages/IPython/core/interactiveshell.py:326, in _modified_open(file, *args, **kwargs)
#     319 if file in {0, 1, 2}:
#     320     raise ValueError(
#     321         f"IPython won't let you open fd={file} by default "
#     322         "as it is likely to crash IPython. If you know what you are doing, "
#     323         "you can use builtins' open."
#     324     )
# --> 326 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './delegate_game_logs/claude-3-5-sonnet-20241022_GPSA_50_450_team0.7_temp0.0_1749479584_game_data_evaluated.json'

# %%
diff_choice_list[6]
# Out:
# ({'subject_id': 'claude-3-5-sonnet-20241022_GPSA_50_450_team0.7_temp0.0',
#   'phase': 2,
#   'trial_in_phase': 193,
#   'question_id': 'gpqa_train_recjgMJaMxz4ESDF2',
#   'question_text': "Compounds that have the same molecular formula but are different in their structural arrangement are known as isomers. Isomers have two types, constitutional isomers and stereoisomers. Constitutional isomers have the same molecular formula but differ in their structures. In stereoisomers, molecules are connected in the same way, but their arrangements in space are different.\nWhich of the following organic moieties show optical isomerism?\n\n1. dimethyl 6,6'-dinitro-[1,1'-biphenyl]-2,2'-dicarboxylate\n2. methyl 2-hydroxypropanoate\n3. benzophenone\n4. dimethyl fumarate",
#   'correct_answer': '1 and 2',
#   'timestamp': 1749480176.218984,
#   'subject_answer': '2 (methyl 2-hydroxypropanoate)\n\nThis compound has a chiral carbon with four different substituents: -H, -OH, -CH3, and -COOCH3.',
#   'subject_correct': False,
#   'teammate_answer': None,
#   'teammate_correct': None,
#   'delegation_choice': 'Self',
#   'team_answer': '2 (methyl 2-hydroxypropanoate)\n\nThis compound has a chiral carbon with four different substituents: -H, -OH, -CH3, and -COOCH3.',
#   'team_correct': False,
#   'probs': None,
#   'evaluation_method': 'llm_plurality',
#   'judgments': {'gpt-4o-2024-08-06': 'NO',
#    'gemini-2.0-flash-001': 'NO',
#    'deepseek-chat': 'NO'}},
#  {'subject_id': 'claude-3-5-sonnet-20241022_GPSA_50_450_nohistory_summary_team0.5_temp0.0',
#   'phase': 2,
#   'trial_in_phase': 193,
#   'question_id': 'gpqa_train_recjgMJaMxz4ESDF2',
#   'question_text': "Compounds that have the same molecular formula but are different in their structural arrangement are known as isomers. Isomers have two types, constitutional isomers and stereoisomers. Constitutional isomers have the same molecular formula but differ in their structures. In stereoisomers, molecules are connected in the same way, but their arrangements in space are different.\nWhich of the following organic moieties show optical isomerism?\n\n1. dimethyl 6,6'-dinitro-[1,1'-biphenyl]-2,2'-dicarboxylate\n2. methyl 2-hydroxypropanoate\n3. benzophenone\n4. dimethyl fumarate",
#   'correct_answer': '1 and 2',
#   'timestamp': 1749560101.7081861,
#   'subject_answer': 'Let me analyze this carefully. To show optical isomerism, a molecule needs to have a chiral center (typically a carbon with 4 different substituents) or axis of chirality.\n\nLooking at the options:\n1. Biphenyl derivative - can show axial chirality due to restricted rotation\n2. Methyl 2-hydroxypropanoate - has a chiral center (carbon with -OH, -COOCH3, -CH3, and -H)\n3. Benzophenone - no chiral center\n4. Dimethyl fumarate - no chiral center\n\nOptions 1 and 2 show optical isomerism.\n\nThe answer is: 1, 2',
#   'subject_correct': True,
#   'teammate_answer': None,
#   'teammate_correct': None,
#   'delegation_choice': 'Self',
#   'team_answer': 'Let me analyze this carefully. To show optical isomerism, a molecule needs to have a chiral center (typically a carbon with 4 different substituents) or axis of chirality.\n\nLooking at the options:\n1. Biphenyl derivative - can show axial chirality due to restricted rotation\n2. Methyl 2-hydroxypropanoate - has a chiral center (carbon with -OH, -COOCH3, -CH3, and -H)\n3. Benzophenone - no chiral center\n4. Dimethyl fumarate - no chiral center\n\nOptions 1 and 2 show optical isomerism.\n\nThe answer is: 1, 2',
#   'team_correct': True,
#   'probs': None,
#   'evaluation_method': 'llm_plurality',
#   'judgments': {'gpt-4o-2024-08-06': 'YES',
#    'gemini-2.0-flash-001': 'YES',
#    'deepseek-chat': 'YES'}})

# %%
def contingency(delegate: np.ndarray, correct: np.ndarray):
    """
    delegate : bool[N]   True -> model delegated
    correct  : bool[N]   True -> model would be correct on its own
    returns  : TP, FN, FP, TN as ints
    """
    TP = np.sum(delegate  & ~correct)   # delegate & wrong
    FN = np.sum(~delegate & ~correct)   # keep     & wrong
    FP = np.sum(delegate  &  correct)   # delegate & right
    TN = np.sum(~delegate &  correct)   # keep     & right
    return TP, FN, FP, TN

def lift_mcc_stats(tp, fn, fp, tn, p0, n_boot=2000, seed=0):
    """
    Parameters
    ----------
    tp, fn, fp, tn : int
        Contingency counts on Phase-2 items  
            tp = delegate & wrong  
            fn = keep & wrong  
            fp = delegate & right  
            tn = keep & right
    p0 : float
        Baseline accuracy to test against (global for RAW, hybrid value for HYBRID)
    Returns
    -------
    dict with point estimates, CIs, and p-values for
        lift   = acc_kept - p0
        mcc    = Matthews correlation
    """
    rng = np.random.default_rng(seed)

    # ---------- point estimates --------------------------------------------
    k         = fn + tn                       # kept items
    kept_acc  = tn / k if k else np.nan
    lift      = kept_acc - p0

    denom = math.sqrt((tp+fp)*(tp+fn)*(tn+fp)*(tn+fn))
    mcc   = (tp*tn - fp*fn) / denom if denom else np.nan

    # ---------- p-values ----------------------------------------------------
    p_lift = binomtest(tn, k, p0, alternative='two-sided').pvalue
    p_mcc  = mcnemar([[tn, fp],
                      [fn, tp]], exact=True).pvalue   # two-sided by default

    # ---------- bootstrap CIs ----------------------------------------------
    N        = tp + fn + fp + tn
    counts   = np.array([tp, fn, fp, tn], int)
    probs    = counts / N

    lifts, mccs = [], []
    for _ in range(n_boot):
        sample = rng.choice(4, size=N, replace=True, p=probs)
        btp, bfn, bfp, btn = np.bincount(sample, minlength=4)

        bk     = bfn + btn
        b_acc  = btn / bk if bk else 0.0
        lifts.append(b_acc - p0)

        bden = math.sqrt((btp+bfp)*(btp+bfn)*(btn+bfp)*(btn+bfn))
        bmcc = (btp*btn - bfp*bfn) / bden if bden else 0.0
        mccs.append(bmcc)

    ci_lift = np.percentile(lifts, [2.5, 97.5])
    ci_mcc  = np.percentile(mccs,  [2.5, 97.5])

    return dict(
        lift       = lift,
        lift_ci    = tuple(ci_lift),
        p_lift     = p_lift,
        mcc        = mcc,
        mcc_ci     = tuple(ci_mcc),
        p_mcc      = p_mcc
    )

...

delegated = np.array(df_model['delegate_choice'], bool)
kept_mask = ~delegated                       # True where model answered itself
cap_corr = np.array(df_model['s_i_capability'], int)   # Baseline correctness from capabilities file
team_corr = np.where(df_model['delegate_choice'] == 0, df_model['team_correct'].fillna(0).astype(int), 0).astype(int) #Real in-game self correctness (only defined when kept)
# Hybrid correctness label 
#    – use real game correctness when the model kept
#    – fallback to baseline correctness when it delegated
true_label = np.where(kept_mask, team_corr, cap_corr)   # 1 = model would be correct

TP, FN, FP, TN = contingency(delegated, cap_corr)
raw_stats = lift_mcc_stats(TP, FN, FP, TN, cap_corr.mean())
log_output(f"Introspection score = {raw_stats['mcc']:.3f} [{raw_stats['mcc_ci'][0]:.3f}, {raw_stats['mcc_ci'][1]:.3f}], p={raw_stats['p_mcc']:.4g}")
delta_d, ci_low, ci_high, p_val = delegate_gap_stats(TP=TP, FN=FN, FP=FP, TN=TN)
log_output(f"Delegate Gap = {delta_d:.3f} [{ci_low:.3f}, {ci_high:.3f}, p={p_val:.4g}]")

TP, FN, FP, TN = contingency(delegated, true_label)
N = (TP+FP+TN+FN)
k   = FN + TN
acc_kept   = TN / k
acc_deleg  = cap_corr[delegated].mean()
p0_hyb     = (k/N)*acc_kept + (1-k/N)*acc_deleg
adj_stats = lift_mcc_stats(TP, FN, FP, TN, p0_hyb)

log_output(f"Adjusted introspection score = {adj_stats['mcc']:.3f} [{adj_stats['mcc_ci'][0]:.3f}, {adj_stats['mcc_ci'][1]:.3f}], p={adj_stats['p_mcc']:.4g}")
delta_d, ci_low, ci_high, p_val = delegate_gap_stats(TP=TP, FN=FN, FP=FP, TN=TN)
log_output(f"Adjusted delegate gap = {delta_d:.3f} [{ci_low:.3f}, {ci_high:.3f}, p={p_val:.4g}]")

log_output(f"Self-acc lift = {raw_stats['lift']:.3f} [{raw_stats['lift_ci'][0]:.3f}, {raw_stats['lift_ci'][1]:.3f}], p={raw_stats['p_lift']:.4g}")

log_output(f"Adjusted self-acc lift = {adj_stats['lift']:.3f} [{adj_stats['lift_ci'][0]:.3f}, {adj_stats['lift_ci'][1]:.3f}], p={adj_stats['p_lift']:.4g}")
